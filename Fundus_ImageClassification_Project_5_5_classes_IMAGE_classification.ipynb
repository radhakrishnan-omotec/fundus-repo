# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/fundus-repo/blob/main/Fundus_ImageClassification_Project_5_5_classes_IMAGE_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image classification

# %% [markdown]
# This tutorial shows how to classify images of flowers using a `tf.keras.Sequential` model and load data using `tf.keras.utils.image_dataset_from_directory`. It demonstrates the following concepts:
#
#
# * Efficiently loading a dataset off disk.
# * Identifying overfitting and applying techniques to mitigate it, including data augmentation and dropout.
#
# This tutorial follows a basic machine learning workflow:
#
# 1. Examine and understand data
# 2. Build an input pipeline
# 3. Build the model
# 4. Train the model
# 5. Test the model
# 6. Improve the model and repeat the process

# %%
# !pip install -q kaggle

# !mkdir -p ~/.kaggle

# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle competitions download -c diabetic-retinopathy-detection

# !kaggle datasets download -d sovitrath/diabetic-retinopathy-224x224-gaussian-filtered
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 7, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 407, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
# Dataset URL: https://www.kaggle.com/datasets/sovitrath/diabetic-retinopathy-224x224-gaussian-filtered
# License(s): CC0-1.0
# Downloading diabetic-retinopathy-224x224-gaussian-filtered.zip to /content
# 100% 427M/427M [00:22<00:00, 23.2MB/s]
# 100% 427M/427M [00:22<00:00, 20.1MB/s]

# %% [markdown]
# ## Setup
#
# Import TensorFlow and other necessary libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download and explore the dataset

# %% [markdown]
# This tutorial uses a dataset of about 3,700 photos of eyes. The dataset contains five sub-directories, one per class:
#
# ```
# gaussian_filtered_images/
#   No_DR/
#   Mild/
#   Moderate/
#   Severe/
#   Proliferate_DR/
# ```

# %%
# Unzip the competition data
# !unzip -q diabetic-retinopathy-detection.zip -d diabetic-retinopathy-detection

# Unzip the dataset
# !unzip -q diabetic-retinopathy-224x224-gaussian-filtered.zip -d diabetic-retinopathy-224x224-gaussian-filtered
# Out:
# unzip:  cannot find or open diabetic-retinopathy-detection.zip, diabetic-retinopathy-detection.zip.zip or diabetic-retinopathy-detection.zip.ZIP.

# %% [markdown]
# After downloading, you should now have a copy of the dataset available. There are 3,670 total images:

# %%
import pathlib
# Define the directory path
data_dir = pathlib.Path('/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images')
# Specify the image file extensions to look for
image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}
# Use pathlib to find all image files in the directory and subdirectories
image_files = [f for f in data_dir.rglob('*') if f.suffix.lower() in image_extensions]
# Count the number of image files
num_images = len(image_files)
print(f"Number of images: {num_images}")
# Out:
# Number of images: 3662

# %% [markdown]
# ## Load data using a Keras utility
#
# Next, load these images off disk using the helpful `tf.keras.utils.image_dataset_from_directory` utility. This will take you from a directory of images on disk to a `tf.data.Dataset` in just a couple lines of code. If you like, you can also write your own data loading code from scratch by visiting the [Load and preprocess images](../load_data/images.ipynb) tutorial.

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# It's good practice to use a validation split when developing your model. Use 80% of the images for training and 20% for validation.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3662 files belonging to 5 classes.
# Using 2930 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3662 files belonging to 5 classes.
# Using 732 files for validation.

# %% [markdown]
# You can find the class names in the `class_names` attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe']

# %% [markdown]
# ## Visualize the data
#
# Here are the first nine images from the training dataset:

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# You will pass these datasets to the Keras `Model.fit` method for training later in this tutorial. If you like, you can also manually iterate over the dataset and retrieve batches of images:

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.
#
# You can call `.numpy()` on the `image_batch` and `labels_batch` tensors to convert them to a `numpy.ndarray`.

# %% [markdown]
# ## Configure the dataset for performance
#
# Make sure to use buffered prefetching, so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data:
#
# - `Dataset.cache` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
# - `Dataset.prefetch` overlaps data preprocessing and model execution while training.
#
# Interested readers can learn more about both methods, as well as how to cache data to disk in the *Prefetching* section of the [Better performance with the tf.data API](../../guide/data_performance.ipynb) guide.

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standardize the data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network; in general you should seek to make your input values small.
#
# Here, you will standardize values to be in the `[0, 1]` range by using `tf.keras.layers.Rescaling`:

# %%
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# There are two ways to use this layer. You can apply it to the dataset by calling `Dataset.map`:

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.03315753 0.9948385

# %% [markdown]
# Or, you can include the layer inside your model definition, which can simplify deployment. Use the second approach here.

# %% [markdown]
# Note: You previously resized images using the `image_size` argument of `tf.keras.utils.image_dataset_from_directory`. If you want to include the resizing logic in your model as well, you can use the `tf.keras.layers.Resizing` layer.

# %% [markdown]
# ## A basic Keras model
#
# ### Create the model
#
# The Keras [Sequential](https://www.tensorflow.org/guide/keras/sequential_model) model consists of three convolution blocks (`tf.keras.layers.Conv2D`) with a max pooling layer (`tf.keras.layers.MaxPooling2D`) in each of them. There's a fully-connected layer (`tf.keras.layers.Dense`) with 128 units on top of it that is activated by a ReLU activation function (`'relu'`). This model has not been tuned for high accuracy; the goal of this tutorial is to show a standard approach.

# %%
num_classes = len(class_names)
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ### Compile the model
#
# For this tutorial, choose the `tf.keras.optimizers.Adam` optimizer and `tf.keras.losses.SparseCategoricalCrossentropy` loss function. To view training and validation accuracy for each training epoch, pass the `metrics` argument to `Model.compile`.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Model summary
#
# View all the layers of the network using the Keras `Model.summary` method:

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,285 (15.22 MB)
#  Trainable params: 3,989,285 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model

# %% [markdown]
# Train the model for 10 epochs with the Keras `Model.fit` method:

# %%
epochs=10
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 17s 129ms/step - accuracy: 0.5826 - loss: 1.1943 - val_accuracy: 0.6913 - val_loss: 0.8186
# Epoch 2/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7186 - loss: 0.7899 - val_accuracy: 0.6872 - val_loss: 0.8499
# Epoch 3/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7205 - loss: 0.7601 - val_accuracy: 0.7295 - val_loss: 0.7380
# Epoch 4/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7352 - loss: 0.7168 - val_accuracy: 0.7186 - val_loss: 0.7320
# Epoch 5/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7319 - loss: 0.6957 - val_accuracy: 0.7158 - val_loss: 0.7683
# Epoch 6/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7602 - loss: 0.6423 - val_accuracy: 0.7309 - val_loss: 0.7174
# Epoch 7/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7789 - loss: 0.5993 - val_accuracy: 0.7377 - val_loss: 0.7386
# Epoch 8/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7700 - loss: 0.6262 - val_accuracy: 0.7336 - val_loss: 0.7209
# Epoch 9/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.8062 - loss: 0.5335 - val_accuracy: 0.7281 - val_loss: 0.7236
# Epoch 10/10
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8167 - loss: 0.4986 - val_accuracy: 0.7281 - val_loss: 0.7526

# %% [markdown]
# ## Visualize training results

# %% [markdown]
# Create plots of the loss and accuracy on the training and validation sets:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 12))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# The plots show that training accuracy and validation accuracy are off by large margins, and the model has achieved only around 60% accuracy on the validation set.
#
# The following tutorial sections show how to inspect what went wrong and try to increase the overall performance of the model.

# %% [markdown]
# ## Overfitting

# %% [markdown]
# In the plots above, the training accuracy is increasing linearly over time, whereas validation accuracy stalls around 60% in the training process. Also, the difference in accuracy between training and validation accuracy is noticeable—a sign of [overfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit).
#
# When there are a small number of training examples, the model sometimes learns from noises or unwanted details from training examples—to an extent that it negatively impacts the performance of the model on new examples. This phenomenon is known as overfitting. It means that the model will have a difficult time generalizing on a new dataset.
#
# There are multiple ways to fight overfitting in the training process. In this tutorial, you'll use *data augmentation* and add *dropout* to your model.

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# Overfitting generally occurs when there are a small number of training examples. [Data augmentation](./data_augmentation.ipynb) takes the approach of generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.
#
# You will implement data augmentation using the following Keras preprocessing layers: `tf.keras.layers.RandomFlip`, `tf.keras.layers.RandomRotation`, and `tf.keras.layers.RandomZoom`. These can be included inside your model like other layers, and run on the GPU.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %% [markdown]
# Visualize a few augmented examples by applying data augmentation to the same image several times:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# You will add data augmentation to your model before training in the next step.

# %%
# Count the number of image files
num_images = len(images)
print(f"Number of images: {num_images}")
# Out:
# Number of images: 32

# %% [markdown]
# ## Dropout
#
# Another technique to reduce overfitting is to introduce [dropout](https://developers.google.com/machine-learning/glossary#dropout_regularization){:.external} regularization to the network.
#
# When you apply dropout to a layer, it randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.
#
# Create a new neural network with `tf.keras.layers.Dropout` before training it using the augmented images:

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %% [markdown]
# ## Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_2 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ outputs (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,285 (15.22 MB)
#  Trainable params: 3,989,285 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 150
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8021 - loss: 0.4981 - val_accuracy: 0.7445 - val_loss: 0.7083
# Epoch 2/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8062 - loss: 0.5252 - val_accuracy: 0.7486 - val_loss: 0.7830
# Epoch 3/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8125 - loss: 0.5011 - val_accuracy: 0.7336 - val_loss: 0.8206
# Epoch 4/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.7973 - loss: 0.5326 - val_accuracy: 0.6858 - val_loss: 0.7467
# Epoch 5/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8008 - loss: 0.5304 - val_accuracy: 0.7486 - val_loss: 0.6772
# Epoch 6/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8160 - loss: 0.4921 - val_accuracy: 0.7145 - val_loss: 0.7954
# Epoch 7/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8080 - loss: 0.5050 - val_accuracy: 0.7350 - val_loss: 0.7635
# Epoch 8/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8042 - loss: 0.5176 - val_accuracy: 0.7186 - val_loss: 0.8072
# Epoch 9/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8086 - loss: 0.5097 - val_accuracy: 0.7117 - val_loss: 0.9617
# Epoch 10/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8096 - loss: 0.4965 - val_accuracy: 0.7363 - val_loss: 0.7061
# Epoch 11/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8004 - loss: 0.5040 - val_accuracy: 0.7049 - val_loss: 0.8066
# Epoch 12/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7854 - loss: 0.5437 - val_accuracy: 0.7527 - val_loss: 0.7164
# Epoch 13/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8124 - loss: 0.4961 - val_accuracy: 0.7268 - val_loss: 0.8645
# Epoch 14/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8236 - loss: 0.4718 - val_accuracy: 0.7172 - val_loss: 0.8433
# Epoch 15/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8125 - loss: 0.4813 - val_accuracy: 0.7555 - val_loss: 0.7539
# Epoch 16/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7947 - loss: 0.5135 - val_accuracy: 0.7377 - val_loss: 0.8353
# Epoch 17/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8230 - loss: 0.4814 - val_accuracy: 0.7459 - val_loss: 0.7925
# Epoch 18/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8280 - loss: 0.4553 - val_accuracy: 0.7350 - val_loss: 0.8271
# Epoch 19/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8067 - loss: 0.4933 - val_accuracy: 0.7404 - val_loss: 0.7774
# Epoch 20/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8134 - loss: 0.4813 - val_accuracy: 0.7555 - val_loss: 0.7185
# Epoch 21/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8275 - loss: 0.4486 - val_accuracy: 0.7527 - val_loss: 0.8073
# Epoch 22/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8300 - loss: 0.4467 - val_accuracy: 0.7377 - val_loss: 0.7711
# Epoch 23/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8246 - loss: 0.4570 - val_accuracy: 0.7145 - val_loss: 0.7827
# Epoch 24/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8348 - loss: 0.4466 - val_accuracy: 0.7350 - val_loss: 0.7407
# Epoch 25/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8184 - loss: 0.4636 - val_accuracy: 0.7459 - val_loss: 0.7809
# Epoch 26/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8204 - loss: 0.4683 - val_accuracy: 0.7486 - val_loss: 0.7792
# Epoch 27/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8317 - loss: 0.4517 - val_accuracy: 0.7172 - val_loss: 0.8428
# Epoch 28/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8382 - loss: 0.4230 - val_accuracy: 0.7459 - val_loss: 0.8078
# Epoch 29/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8207 - loss: 0.4582 - val_accuracy: 0.7473 - val_loss: 0.7934
# Epoch 30/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8303 - loss: 0.4468 - val_accuracy: 0.7295 - val_loss: 0.8292
# Epoch 31/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8358 - loss: 0.4195 - val_accuracy: 0.7213 - val_loss: 0.9637
# Epoch 32/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8268 - loss: 0.4342 - val_accuracy: 0.7186 - val_loss: 0.8885
# Epoch 33/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8438 - loss: 0.4293 - val_accuracy: 0.7391 - val_loss: 0.7814
# Epoch 34/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8281 - loss: 0.4425 - val_accuracy: 0.7432 - val_loss: 0.7963
# Epoch 35/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8252 - loss: 0.4435 - val_accuracy: 0.7336 - val_loss: 0.9036
# Epoch 36/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8506 - loss: 0.4003 - val_accuracy: 0.7145 - val_loss: 0.7908
# Epoch 37/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8291 - loss: 0.4324 - val_accuracy: 0.7322 - val_loss: 0.8368
# Epoch 38/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8379 - loss: 0.4397 - val_accuracy: 0.7391 - val_loss: 0.8049
# Epoch 39/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8447 - loss: 0.4029 - val_accuracy: 0.7104 - val_loss: 0.8521
# Epoch 40/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8482 - loss: 0.4027 - val_accuracy: 0.7404 - val_loss: 0.8035
# Epoch 41/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8428 - loss: 0.4195 - val_accuracy: 0.7486 - val_loss: 0.8250
# Epoch 42/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8325 - loss: 0.4289 - val_accuracy: 0.7486 - val_loss: 0.8113
# Epoch 43/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8411 - loss: 0.4229 - val_accuracy: 0.7254 - val_loss: 0.8973
# Epoch 44/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8400 - loss: 0.4262 - val_accuracy: 0.7486 - val_loss: 0.8515
# Epoch 45/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8454 - loss: 0.4082 - val_accuracy: 0.7186 - val_loss: 0.8581
# Epoch 46/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8396 - loss: 0.4251 - val_accuracy: 0.7432 - val_loss: 0.8813
# Epoch 47/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8523 - loss: 0.3929 - val_accuracy: 0.7268 - val_loss: 0.8199
# Epoch 48/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8604 - loss: 0.3890 - val_accuracy: 0.7418 - val_loss: 0.9220
# Epoch 49/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8501 - loss: 0.3951 - val_accuracy: 0.7514 - val_loss: 0.8709
# Epoch 50/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8419 - loss: 0.3900 - val_accuracy: 0.7432 - val_loss: 0.9427
# Epoch 51/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8514 - loss: 0.3726 - val_accuracy: 0.7363 - val_loss: 0.9229
# Epoch 52/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8442 - loss: 0.3988 - val_accuracy: 0.7336 - val_loss: 0.9351
# Epoch 53/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8471 - loss: 0.3946 - val_accuracy: 0.7281 - val_loss: 0.9591
# Epoch 54/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8349 - loss: 0.4450 - val_accuracy: 0.7254 - val_loss: 0.8806
# Epoch 55/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8447 - loss: 0.4084 - val_accuracy: 0.7391 - val_loss: 0.8635
# Epoch 56/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8591 - loss: 0.3665 - val_accuracy: 0.7295 - val_loss: 1.0127
# Epoch 57/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8518 - loss: 0.3979 - val_accuracy: 0.7445 - val_loss: 0.9930
# Epoch 58/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8547 - loss: 0.3893 - val_accuracy: 0.7063 - val_loss: 1.1251
# Epoch 59/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8593 - loss: 0.3520 - val_accuracy: 0.7418 - val_loss: 0.9049
# Epoch 60/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8752 - loss: 0.3502 - val_accuracy: 0.7568 - val_loss: 0.8791
# Epoch 61/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8486 - loss: 0.3866 - val_accuracy: 0.7459 - val_loss: 0.9171
# Epoch 62/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8680 - loss: 0.3553 - val_accuracy: 0.7391 - val_loss: 1.0298
# Epoch 63/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8610 - loss: 0.3566 - val_accuracy: 0.7432 - val_loss: 0.9590
# Epoch 64/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8412 - loss: 0.4136 - val_accuracy: 0.7391 - val_loss: 1.0286
# Epoch 65/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8579 - loss: 0.3786 - val_accuracy: 0.7445 - val_loss: 0.9280
# Epoch 66/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8418 - loss: 0.3895 - val_accuracy: 0.7350 - val_loss: 0.9825
# Epoch 67/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8673 - loss: 0.3504 - val_accuracy: 0.7363 - val_loss: 0.9165
# Epoch 68/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8717 - loss: 0.3324 - val_accuracy: 0.7309 - val_loss: 0.9686
# Epoch 69/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8679 - loss: 0.3519 - val_accuracy: 0.7363 - val_loss: 0.8887
# Epoch 70/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8580 - loss: 0.3568 - val_accuracy: 0.7486 - val_loss: 0.9194
# Epoch 71/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8541 - loss: 0.3960 - val_accuracy: 0.7432 - val_loss: 0.9162
# Epoch 72/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8595 - loss: 0.3827 - val_accuracy: 0.7281 - val_loss: 0.8477
# Epoch 73/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8789 - loss: 0.3464 - val_accuracy: 0.7418 - val_loss: 0.9573
# Epoch 74/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8673 - loss: 0.3549 - val_accuracy: 0.7445 - val_loss: 0.8729
# Epoch 75/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8577 - loss: 0.3649 - val_accuracy: 0.7459 - val_loss: 1.0029
# Epoch 76/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8608 - loss: 0.3607 - val_accuracy: 0.7527 - val_loss: 0.8777
# Epoch 77/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8660 - loss: 0.3611 - val_accuracy: 0.7596 - val_loss: 0.9565
# Epoch 78/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8577 - loss: 0.3793 - val_accuracy: 0.7555 - val_loss: 0.9696
# Epoch 79/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8647 - loss: 0.3743 - val_accuracy: 0.7350 - val_loss: 0.9586
# Epoch 80/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8840 - loss: 0.3218 - val_accuracy: 0.7459 - val_loss: 1.0268
# Epoch 81/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8749 - loss: 0.3275 - val_accuracy: 0.7445 - val_loss: 0.9733
# Epoch 82/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8743 - loss: 0.3327 - val_accuracy: 0.7404 - val_loss: 0.9830
# Epoch 83/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8755 - loss: 0.3073 - val_accuracy: 0.7377 - val_loss: 1.0312
# Epoch 84/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8874 - loss: 0.3125 - val_accuracy: 0.7377 - val_loss: 1.1123
# Epoch 85/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8666 - loss: 0.3529 - val_accuracy: 0.7514 - val_loss: 1.0996
# Epoch 86/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8753 - loss: 0.3413 - val_accuracy: 0.7377 - val_loss: 1.0876
# Epoch 87/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8707 - loss: 0.3274 - val_accuracy: 0.7254 - val_loss: 1.0788
# Epoch 88/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8794 - loss: 0.3300 - val_accuracy: 0.7432 - val_loss: 0.9966
# Epoch 89/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8777 - loss: 0.3127 - val_accuracy: 0.7432 - val_loss: 1.1470
# Epoch 90/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8747 - loss: 0.2992 - val_accuracy: 0.7568 - val_loss: 1.1470
# Epoch 91/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8930 - loss: 0.2999 - val_accuracy: 0.7473 - val_loss: 1.1602
# Epoch 92/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8733 - loss: 0.3164 - val_accuracy: 0.7486 - val_loss: 1.0320
# Epoch 93/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8624 - loss: 0.3456 - val_accuracy: 0.7459 - val_loss: 1.0440
# Epoch 94/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8913 - loss: 0.2852 - val_accuracy: 0.7145 - val_loss: 1.3880
# Epoch 95/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8889 - loss: 0.2890 - val_accuracy: 0.7350 - val_loss: 1.1423
# Epoch 96/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8783 - loss: 0.3144 - val_accuracy: 0.7145 - val_loss: 1.2125
# Epoch 97/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8918 - loss: 0.2998 - val_accuracy: 0.7131 - val_loss: 1.1430
# Epoch 98/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8826 - loss: 0.3103 - val_accuracy: 0.7404 - val_loss: 1.1012
# Epoch 99/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8987 - loss: 0.2876 - val_accuracy: 0.7295 - val_loss: 1.1690
# Epoch 100/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8918 - loss: 0.3003 - val_accuracy: 0.7486 - val_loss: 1.0092
# Epoch 101/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8803 - loss: 0.3019 - val_accuracy: 0.7391 - val_loss: 1.2245
# Epoch 102/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8809 - loss: 0.3076 - val_accuracy: 0.7322 - val_loss: 1.2554
# Epoch 103/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8787 - loss: 0.3385 - val_accuracy: 0.7500 - val_loss: 1.0144
# Epoch 104/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8946 - loss: 0.2848 - val_accuracy: 0.7391 - val_loss: 1.1641
# Epoch 105/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9001 - loss: 0.2721 - val_accuracy: 0.7268 - val_loss: 1.1940
# Epoch 106/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8948 - loss: 0.2889 - val_accuracy: 0.7391 - val_loss: 1.3903
# Epoch 107/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9022 - loss: 0.2667 - val_accuracy: 0.7350 - val_loss: 1.0271
# Epoch 108/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8965 - loss: 0.2656 - val_accuracy: 0.7281 - val_loss: 1.1029
# Epoch 109/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8937 - loss: 0.2895 - val_accuracy: 0.7391 - val_loss: 1.0682
# Epoch 110/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9129 - loss: 0.2554 - val_accuracy: 0.7363 - val_loss: 1.0660
# Epoch 111/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8917 - loss: 0.2877 - val_accuracy: 0.7432 - val_loss: 1.1134
# Epoch 112/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8993 - loss: 0.2658 - val_accuracy: 0.7391 - val_loss: 1.2275
# Epoch 113/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8872 - loss: 0.2787 - val_accuracy: 0.7254 - val_loss: 1.2188
# Epoch 114/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8807 - loss: 0.3195 - val_accuracy: 0.7418 - val_loss: 1.0796
# Epoch 115/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8809 - loss: 0.3019 - val_accuracy: 0.7309 - val_loss: 1.1660
# Epoch 116/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8910 - loss: 0.2698 - val_accuracy: 0.7363 - val_loss: 1.2585
# Epoch 117/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8992 - loss: 0.2809 - val_accuracy: 0.7322 - val_loss: 1.2355
# Epoch 118/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8940 - loss: 0.2678 - val_accuracy: 0.7500 - val_loss: 1.1626
# Epoch 119/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.9067 - loss: 0.2687 - val_accuracy: 0.7418 - val_loss: 1.1704
# Epoch 120/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8944 - loss: 0.2818 - val_accuracy: 0.7281 - val_loss: 1.2319
# Epoch 121/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8986 - loss: 0.2657 - val_accuracy: 0.7514 - val_loss: 1.1490
# Epoch 122/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8923 - loss: 0.2669 - val_accuracy: 0.7582 - val_loss: 1.1266
# Epoch 123/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8900 - loss: 0.2936 - val_accuracy: 0.7418 - val_loss: 1.1278
# Epoch 124/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9045 - loss: 0.2735 - val_accuracy: 0.7486 - val_loss: 1.2928
# Epoch 125/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.9011 - loss: 0.2715 - val_accuracy: 0.7391 - val_loss: 1.2512
# Epoch 126/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9069 - loss: 0.2459 - val_accuracy: 0.7322 - val_loss: 1.3366
# Epoch 127/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8995 - loss: 0.2784 - val_accuracy: 0.7459 - val_loss: 1.0578
# Epoch 128/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8970 - loss: 0.2823 - val_accuracy: 0.7391 - val_loss: 1.2209
# Epoch 129/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9104 - loss: 0.2477 - val_accuracy: 0.7473 - val_loss: 1.1181
# Epoch 130/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9073 - loss: 0.2363 - val_accuracy: 0.7391 - val_loss: 1.1893
# Epoch 131/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8904 - loss: 0.2738 - val_accuracy: 0.7391 - val_loss: 1.3117
# Epoch 132/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8963 - loss: 0.2801 - val_accuracy: 0.7227 - val_loss: 1.3933
# Epoch 133/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8906 - loss: 0.2691 - val_accuracy: 0.7445 - val_loss: 1.3018
# Epoch 134/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9047 - loss: 0.2557 - val_accuracy: 0.7445 - val_loss: 1.2982
# Epoch 135/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8891 - loss: 0.2795 - val_accuracy: 0.7336 - val_loss: 1.2680
# Epoch 136/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9066 - loss: 0.2513 - val_accuracy: 0.7404 - val_loss: 1.1608
# Epoch 137/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9143 - loss: 0.2361 - val_accuracy: 0.7377 - val_loss: 1.4487
# Epoch 138/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8949 - loss: 0.2843 - val_accuracy: 0.7486 - val_loss: 1.2393
# Epoch 139/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.9001 - loss: 0.2733 - val_accuracy: 0.7527 - val_loss: 1.2840
# Epoch 140/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9016 - loss: 0.2585 - val_accuracy: 0.7486 - val_loss: 1.3179
# Epoch 141/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.9086 - loss: 0.2445 - val_accuracy: 0.7418 - val_loss: 1.5122
# Epoch 142/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9119 - loss: 0.2386 - val_accuracy: 0.7527 - val_loss: 1.2619
# Epoch 143/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8995 - loss: 0.2656 - val_accuracy: 0.7445 - val_loss: 1.2690
# Epoch 144/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.9143 - loss: 0.2416 - val_accuracy: 0.7555 - val_loss: 1.2976
# Epoch 145/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.9144 - loss: 0.2251 - val_accuracy: 0.7377 - val_loss: 1.3682
# Epoch 146/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9092 - loss: 0.2487 - val_accuracy: 0.7377 - val_loss: 1.3787
# Epoch 147/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9079 - loss: 0.2489 - val_accuracy: 0.7254 - val_loss: 1.3416
# Epoch 148/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9185 - loss: 0.2169 - val_accuracy: 0.7377 - val_loss: 1.3064
# Epoch 149/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.9132 - loss: 0.2248 - val_accuracy: 0.7363 - val_loss: 1.2693
# Epoch 150/150
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.9221 - loss: 0.2214 - val_accuracy: 0.7527 - val_loss: 1.3507

# %% [markdown]
# ## Visualize training results
#
# After applying data augmentation and `tf.keras.layers.Dropout`, there is less overfitting than before, and training and validation accuracy are closer aligned:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ## Predict on new data

# %%
# !git clone https://github.com/radhakrishnan-omotec/fundus-repo.git
# Out:
# fatal: destination path 'fundus-repo' already exists and is not an empty directory.

# %% [markdown]
# Use your model to classify an image that wasn't included in the training or validation sets.

# %% [markdown]
# Note: Data augmentation and dropout layers are inactive at inference time.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        # Calculate confidence as a percentage
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/mild_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Mild'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 0024cdab0c1e.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        # Calculate confidence as a percentage
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/moderate_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Moderate'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 000c1434d8d7.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        # Calculate confidence as a percentage
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/No_DR_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/No_DR'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 002c21358ce6.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/Proliferate_DR_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Proliferate_DR'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 001639a390f0.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/Severe_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 0104b032c141.png with 100.00% confidence.

# %% [markdown]
# This code compares an uploaded image to each image in a dataset using Mean Squared Error to determine if they match, returning the filename of any matching image. It preprocesses images to a specified size and handles non-file entries and errors gracefully.

# %% [markdown]
# ## Use TensorFlow Lite
#
# TensorFlow Lite is a set of tools that enables on-device machine learning by helping developers run their models on mobile, embedded, and edge devices.

# %% [markdown]
# ### Convert the Keras Sequential model to a TensorFlow Lite model
#
# To use the trained model with on-device applications, first [convert it](https://www.tensorflow.org/lite/models/convert) to a smaller and more efficient model format called a [TensorFlow Lite](https://www.tensorflow.org/lite/) model.
#
# In this example, take the trained Keras Sequential model and use `tf.lite.TFLiteConverter.from_keras_model` to generate a [TensorFlow Lite](https://www.tensorflow.org/lite/) model:

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('model_fundus.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpxk55usap'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name='keras_tensor_15')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   137315409435408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137315409436640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137315409438048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137315408796960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137315408800480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137315408805408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137315408805232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137315408797312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137315408798896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137315408795904: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# The TensorFlow Lite model you saved in the previous step can contain several function signatures. The Keras model converter API uses the default signature automatically. Learn more about [TensorFlow Lite signatures](https://www.tensorflow.org/lite/guide/signatures).

# %% [markdown]
# ### Run the TensorFlow Lite model
#
# You can access the TensorFlow Lite saved model signatures in Python via the `tf.lite.Interpreter` class.
#
# Load the model with the `Interpreter`:

# %%
TF_MODEL_FILE_PATH = 'model_fundus.tflite' # The default path to the saved TensorFlow Lite model

interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)

# %% [markdown]
# Print the signatures from the converted model to obtain the names of the inputs (and outputs):

# %%
interpreter.get_signature_list()
# Out:
# {'serving_default': {'inputs': ['keras_tensor_15'], 'outputs': ['output_0']}}

# %% [markdown]
# In this example, you have one default signature called `serving_default`. In addition, the name of the `'inputs'` is `'sequential_1_input'`, while the `'outputs'` are called `'outputs'`. You can look up these first and last Keras layer names when running `Model.summary`, as demonstrated earlier in this tutorial.
#
# Now you can test the loaded TensorFlow Model by performing inference on a sample image with `tf.lite.Interpreter.get_signature_runner` by passing the signature name as follows:

# %%
classify_lite = interpreter.get_signature_runner('serving_default')
classify_lite

# %% [markdown]
# #  LOCAL TEST CODE (ONLY)

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
from google.colab import files

# JavaScript to take a photo and return it as a base64 string
def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
    async function takePhoto(quality) {
        const div = document.createElement('div');
        const capture = document.createElement('button');
        capture.textContent = 'Capture';
        document.body.appendChild(div);
        div.appendChild(capture);

        // Setup camera stream
        const video = document.createElement('video');
        video.style.display = 'block';
        const stream = await navigator.mediaDevices.getUserMedia({video: true});
        div.appendChild(video);
        video.srcObject = stream;
        await video.play();

        // Wait for capture button to be clicked
        await new Promise((resolve) => capture.onclick = resolve);

        // Capture photo
        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        canvas.getContext('2d').drawImage(video, 0, 0);
        stream.getTracks().forEach(track => track.stop());
        div.remove();
        return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
    display(js)
    data = eval_js(f'takePhoto({quality})')
    binary = b64decode(data.split(',')[1])

    # Save the image locally
    with open(filename, 'wb') as f:
        f.write(binary)

    print(f"Saved photo to {filename}")

    return filename

# Capture a photo and save it
photo_filename = take_photo()

# %% [markdown]
# #Prediction Testing Phase

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil

# Define the destination folder in your Google Drive
drive_folder = '/content/drive/MyDrive/retinopathy fundus'

# Move the captured photo to Google Drive
shutil.move(photo_filename, drive_folder)

print(f"Moved {photo_filename} to {drive_folder}")
# Out:
# Moved photo.jpg to /content/drive/MyDrive/retinopathy fundus

# %%
image_path = '/content/drive/My Drive/Colab Notebooks/photo.jpg'  # Replace with your actual image path

# %% [markdown]
# # Prediction with webcam Fundus images

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Define the paths
image_path = '/content/fundus-repo/moderate_retinopathy_test_image.png'  # Replace with your actual image path
TF_MODEL_FILE_PATH = 'model_fundus.tflite'  # The default path to the saved TensorFlow Lite model

# Define class names corresponding to your model output
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = Image.open(img_path).convert('RGB')
    img = img.resize(target_size)
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# Preprocess the image
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (batch_size, height, width, channels)
image_data = load_and_preprocess_image(image_path, input_shape)

# Ensure the input tensor's type matches the model's expected type
input_data = image_data.astype(input_details[0]['dtype'])

# Set input tensor
interpreter.set_tensor(input_details[0]['index'], input_data)

# Run inference
interpreter.invoke()

# Get the output tensor
output_data = interpreter.get_tensor(output_details[0]['index'])

# Get predicted class index
predicted_class_index = np.argmax(output_data[0])
predicted_class_name = class_names[predicted_class_index]

print(f"Predicted class index: {predicted_class_index}")
print(f"Predicted class name: {predicted_class_name}")

# Show the image along with the prediction
img = Image.open(image_path)
plt.imshow(img)
plt.title(f"Predicted: {predicted_class_name}")
plt.axis('off')
plt.show()
# Out:
# Predicted class index: 2
# Predicted class name: Moderate

# %% [markdown]
# Similar to what you did earlier in the tutorial, you can use the TensorFlow Lite model to classify images that weren't included in the training or validation sets.
#
# You have already tensorized that image and saved it as `img_array`. Now, pass it to the first argument (the name of the `'inputs'`) of the loaded TensorFlow Lite model (`predictions_lite`), compute softmax activations, and then print the prediction for the class with the highest computed probability.

# %% [markdown]
# Of the five classes—`'No_DR'`, `'Mild'`, `'Moderate'`, `' Severe'` and `'Proliferate_DR'`

# %% [markdown]
# #Prediction from Webcam Test Data

# %%
import tensorflow as tf
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from google.colab import output
import time

# Define the TensorFlow Lite model path and class names
TF_MODEL_FILE_PATH = 'model_fundus.tflite'  # Ensure the file is uploaded to the Colab environment
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Function to preprocess the frame
def preprocess_frame(frame, target_size):
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert from BGR to RGB
    img = cv2.resize(img, target_size)  # Resize to the target size
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array

# Get the model's input shape
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (height, width)

# Initialize webcam capture
def capture_frame():
    js = """
    async function captureWebcam() {
        const video = document.createElement('video');
        video.style.position = 'fixed';
        video.style.top = '0';
        video.style.left = '0';
        video.style.width = '100%';
        video.style.height = '100%';
        video.style.zIndex = '1000';
        document.body.appendChild(video);

        const stream = await navigator.mediaDevices.getUserMedia({ video: true });
        video.srcObject = stream;
        await video.play();

        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        const ctx = canvas.getContext('2d');

        for (let i = 0; i < 100; i++) {
            ctx.drawImage(video, 0, 0, canvas.width, canvas.height);
            const imgData = canvas.toDataURL('image/jpeg');
            google.colab.kernel.invokeFunction('notebook.capture', [imgData], {});
            await new Promise(resolve => setTimeout(resolve, 100));
        }

        video.pause();
        stream.getTracks()[0].stop();
        document.body.removeChild(video);
    }
    captureWebcam();
    """
    output.eval_js(js)

# Callback to capture the frame from JS
def capture_callback(image_data):
    image_data = image_data.split(',')[1]  # Remove the ....frombuffer(base64.b64decode(image_data), np.uint8)
    frame = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
    return frame

# Register the callback function
output.register_callback('notebook.capture', capture_callback)

print("Starting webcam. Please allow camera access.")
capture_frame()

# Start processing the frames
while True:
    ret, frame = cap.read()  # Frame bytes if isn't>

# %%
import base64
from google.colab import output
import cv2

# Function to preprocess and predict the class from a frame
def preprocess_and_predict(frame):
    # Preprocess the frame
    input_data = preprocess_frame(frame, input_shape).astype(input_details[0]['dtype'])

    # Set input tensor
    interpreter.set_tensor(input_details[0]['index'], input_data)

    # Run inference
    interpreter.invoke()

    # Get the output tensor
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # Get predicted class index and name
    predicted_class_index = np.argmax(output_data[0])
    predicted_class_name = class_names[predicted_class_index]

    return predicted_class_name

# Main function to capture and process frames
def capture_frame():
    js_code = """
        async function captureWebcam() {
            const video = document.createElement('video');
            video.style.display = 'none';
            document.body.appendChild(video);

            const stream = await navigator.mediaDevices.getUserMedia({ video: true });
            video.srcObject = stream;
            await video.play();

            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            const ctx = canvas.getContext('2d');

            for (let i = 0; i < 1; i++) {
                ctx.drawImage(video, 0, 0, canvas.width, canvas.height);
                const imageData = canvas.toDataURL('image/jpeg');
                google.colab.kernel.invokeFunction('notebook.capture_frame', [imageData], {});
                await new Promise(resolve => setTimeout(resolve, 1000));
            }

            stream.getTracks()[0].stop();
            document.body.removeChild(video);
        }
        captureWebcam();
    """
    output.eval_js(js_code)

# Callback function to handle the frame data from JavaScript
def handle_frame(data):
    # Decode the base64-encoded image
    image_data = data.split(',')[1]
    image_bytes = base64.b64decode(image_data)
    nparr = np.frombuffer(image_bytes, np.uint8)
    frame = cv2.imdecode(nparr, cv2.IMREAD_COLOR)

    # Process the frame and get prediction
    predicted_class_name = preprocess_and_predict(frame)

    # Display the result
    cv2_imshow(frame)
    print(f"Prediction: {predicted_class_name}")

# Register the callback function for frame capture
output.register_callback('notebook.capture_frame', handle_frame)

# Capture and process frames
print("Starting webcam. Please allow camera access.")
capture_frame()
# Out:
# Starting webcam. Please allow camera access.
# <PIL.Image.Image image mode=RGB size=640x480>
# Prediction: Moderate

# %% [markdown]
# #Standalone Code to test in RPI 5

# %%
import tensorflow as tf
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# Define the TensorFlow Lite model path and class names
TF_MODEL_FILE_PATH = 'model_fundus.tflite'  # The default path to the saved TensorFlow Lite model
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Function to preprocess the frame
def preprocess_frame(frame, target_size):
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert from BGR to RGB
    img = cv2.resize(img, target_size)  # Resize to the target size
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array

# Get the model's input shape
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (height, width)

# Access the webcam
cap = cv2.VideoCapture(0)  # Open the default camera (change the index if needed)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

print("Press 'q' to quit.")

while True:
    ret, frame = cap.read()  # Capture a frame from the webcam
    if not ret:
        print("Error: Failed to capture image.")
        break

    # Preprocess the frame
    input_data = preprocess_frame(frame, input_shape)

    # Ensure the input tensor's type matches the model's expected type
    input_data = input_data.astype(input_details[0]['dtype'])

    # Set input tensor
    interpreter.set_tensor(input_details[0]['index'], input_data)

    # Run inference
    interpreter.invoke()

    # Get the output tensor
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # Get predicted class index and name
    predicted_class_index = np.argmax(output_data[0])
    predicted_class_name = class_names[predicted_class_index]

    # Display the prediction on the frame
    cv2.putText(
        frame,
        f"Prediction: {predicted_class_name}",
        (10, 30),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 255, 0),
        2
    )

    # Show the frame with prediction
    cv2.imshow("Webcam Feed", frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
