# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/fundus-repo/blob/main/Fundus_ISEF_FINAL_FULL_2_Data_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CNN based Vision Transformer with Swin Vision Transformer Image Classification for highest accuracy in google Colab notebook format

# %% [markdown]
# Below is an enhanced Google Colab notebook that upgrades the previous AlexNet implementation to the Swin Transformer (specifically Swin Vision, a large variant), targeting the highest accuracy for classifying 3,700 fundus images into 5 Diabetic Retinopathy classes. Swin Transformer, introduced by Liu et al. (2021), leverages shifted window-based self-attention for superior performance (~87-89% ImageNet Top-1, 97-99% with fine-tuning on small datasets), surpassing CNNs like AlexNet and EfficientNetV2-L. With ~197M parameters, Swin-L is a high-end Vision Transformer (ViT) variant optimized for accuracy, retaining the 7-step structure and adapting to its transformer architecture.
#
# ##NOTE
# This implementation uses the tf.keras.applications.SwinTransformerL (assuming TensorFlow support by March 2025) or a custom implementation if unavailable natively, maximizing accuracy for your task.

# %% [markdown]
# # Google Colab Notebook: Data Visualizations : Vision Transformer with Swin Transformer for Fundus Image Classification

# %%
from google.colab import drive
import os

# Unmount the drive if it's already mounted
if os.path.ismount('/content/drive'):
    drive.flush_and_unmount()
    print("Drive unmounted successfully.")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.Accuracy and Loss Graphs

# %%
training_logs = pd.read_csv("/content/drive/MyDrive/ANUSKHA_MANOJ_IRIS/model_history/FULL-2_log.csv")

# %%
training_logs.head()
# Out:
#    epoch       acc  learning_rate      loss   val_acc  val_loss
# 0      0  0.400878        0.00005  1.316929  0.437870  1.248727
# 1      1  0.448915        0.00005  1.265275  0.449704  1.238064
# 2      2  0.471105        0.00005  1.233575  0.502959  1.214219
# 3      3  0.442087        0.00005  1.271589  0.453649  1.233470
# 4      4  0.486711        0.00005  1.215998  0.495069  1.190059

# %%
# Plotting
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(training_logs['epoch'], training_logs['acc'], label='Training Accuracy')
plt.plot(training_logs['epoch'], training_logs['val_acc'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(training_logs['epoch'], training_logs['loss'], label='Training Loss')
plt.plot(training_logs['epoch'], training_logs['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # 2.Precision Graphs

# %%
training_logs = pd.read_csv("/content/drive/MyDrive/ANUSKHA_MANOJ_IRIS/model_history/FULL-2_new_log_with_precision_recall.csv")

# %%
training_logs.head()
# Out:
#    epoch       acc  learning_rate      loss   val_acc  val_loss  Precision  \
# 0      0  0.400878        0.00005  1.316929  0.437870  1.248727   0.415976
# 1      1  0.448915        0.00005  1.265275  0.449704  1.238064   0.427219
# 2      2  0.471105        0.00005  1.233575  0.502959  1.214219   0.477811
# 3      3  0.442087        0.00005  1.271589  0.453649  1.233470   0.430966
# 4      4  0.486711        0.00005  1.215998  0.495069  1.190059   0.470316
#
#      Recall  F1_Score
# 0  0.394083  0.404790
# 1  0.404734  0.415732
# 2  0.452663  0.464923
# 3  0.408284  0.419422
# 4  0.445562  0.457575

# %%
# Plotting
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(training_logs['epoch'], training_logs['acc'], label='Training Accuracy')
plt.plot(training_logs['epoch'], training_logs['val_acc'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Precision plot
plt.subplot(1, 2, 2)
plt.plot(training_logs['epoch'], training_logs['Precision'], label='Precision')
plt.title('Precision Plots')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend()

# %% [markdown]
# # 3.F1 Score Graphs

# %%
# Plotting
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(training_logs['epoch'], training_logs['acc'], label='Training Accuracy')
plt.plot(training_logs['epoch'], training_logs['val_acc'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# F1_Score plot
plt.subplot(1, 2, 2)
plt.plot(training_logs['epoch'], training_logs['F1_Score'], label='F1_Score')
plt.title('F1_Score Plots')
plt.xlabel('Epoch')
plt.ylabel('F1_Score')
plt.legend()

# %% [markdown]
# # 4.F1 Recall Graphs

# %%
# Plotting
plt.figure(figsize=(12, 6))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(training_logs['epoch'], training_logs['acc'], label='Training Accuracy')
plt.plot(training_logs['epoch'], training_logs['val_acc'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Recall plot
plt.subplot(1, 2, 2)
plt.plot(training_logs['epoch'], training_logs['Recall'], label='Recall')
plt.title('Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ---
