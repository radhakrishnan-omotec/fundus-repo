# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/fundus-repo/blob/main/Fundus_ImageClassification_Project_6_5_classes_IMAGE_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image classification

# %% [markdown]
# This tutorial shows how to classify images of flowers using a `tf.keras.Sequential` model and load data using `tf.keras.utils.image_dataset_from_directory`. It demonstrates the following concepts:
#
#
# * Efficiently loading a dataset off disk.
# * Identifying overfitting and applying techniques to mitigate it, including data augmentation and dropout.
#
# This tutorial follows a basic machine learning workflow:
#
# 1. Examine and understand data
# 2. Build an input pipeline
# 3. Build the model
# 4. Train the model
# 5. Test the model
# 6. Improve the model and repeat the process

# %%
# !pip install -q kaggle

# !mkdir -p ~/.kaggle

# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle competitions download -c diabetic-retinopathy-detection

# !kaggle datasets download -d sovitrath/diabetic-retinopathy-224x224-gaussian-filtered
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/__init__.py", line 7, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/api/kaggle_api_extended.py", line 407, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
# Dataset URL: https://www.kaggle.com/datasets/sovitrath/diabetic-retinopathy-224x224-gaussian-filtered
# License(s): CC0-1.0
# Downloading diabetic-retinopathy-224x224-gaussian-filtered.zip to /content
# 100% 426M/427M [00:19<00:00, 24.9MB/s]
# 100% 427M/427M [00:19<00:00, 22.6MB/s]

# %% [markdown]
# ## Setup
#
# Import TensorFlow and other necessary libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download and explore the dataset

# %% [markdown]
# This tutorial uses a dataset of about 3,700 photos of eyes. The dataset contains five sub-directories, one per class:
#
# ```
# gaussian_filtered_images/
#   No_DR/
#   Mild/
#   Moderate/
#   Severe/
#   Proliferate_DR/
# ```

# %%
# Unzip the competition data
# !unzip -q diabetic-retinopathy-detection.zip -d diabetic-retinopathy-detection

# Unzip the dataset
# !unzip -q diabetic-retinopathy-224x224-gaussian-filtered.zip -d diabetic-retinopathy-224x224-gaussian-filtered
# Out:
# unzip:  cannot find or open diabetic-retinopathy-detection.zip, diabetic-retinopathy-detection.zip.zip or diabetic-retinopathy-detection.zip.ZIP.

# %% [markdown]
# After downloading, you should now have a copy of the dataset available. There are 3,670 total images:

# %%
import pathlib
# Define the directory path
data_dir = pathlib.Path('/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images')
# Specify the image file extensions to look for
image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}
# Use pathlib to find all image files in the directory and subdirectories
image_files = [f for f in data_dir.rglob('*') if f.suffix.lower() in image_extensions]
# Count the number of image files
num_images = len(image_files)
print(f"Number of images: {num_images}")
# Out:
# Number of images: 3662

# %% [markdown]
# ## Load data using a Keras utility
#
# Next, load these images off disk using the helpful `tf.keras.utils.image_dataset_from_directory` utility. This will take you from a directory of images on disk to a `tf.data.Dataset` in just a couple lines of code. If you like, you can also write your own data loading code from scratch by visiting the [Load and preprocess images](../load_data/images.ipynb) tutorial.

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# It's good practice to use a validation split when developing your model. Use 80% of the images for training and 20% for validation.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3662 files belonging to 5 classes.
# Using 2930 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3662 files belonging to 5 classes.
# Using 732 files for validation.

# %% [markdown]
# You can find the class names in the `class_names` attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe']

# %% [markdown]
# ## Visualize the data
#
# Here are the first nine images from the training dataset:

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# You will pass these datasets to the Keras `Model.fit` method for training later in this tutorial. If you like, you can also manually iterate over the dataset and retrieve batches of images:

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.
#
# You can call `.numpy()` on the `image_batch` and `labels_batch` tensors to convert them to a `numpy.ndarray`.

# %% [markdown]
# ## Configure the dataset for performance
#
# Make sure to use buffered prefetching, so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data:
#
# - `Dataset.cache` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
# - `Dataset.prefetch` overlaps data preprocessing and model execution while training.
#
# Interested readers can learn more about both methods, as well as how to cache data to disk in the *Prefetching* section of the [Better performance with the tf.data API](../../guide/data_performance.ipynb) guide.

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standardize the data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network; in general you should seek to make your input values small.
#
# Here, you will standardize values to be in the `[0, 1]` range by using `tf.keras.layers.Rescaling`:

# %%
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# There are two ways to use this layer. You can apply it to the dataset by calling `Dataset.map`:

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.018927282 0.9963352

# %% [markdown]
# Or, you can include the layer inside your model definition, which can simplify deployment. Use the second approach here.

# %% [markdown]
# Note: You previously resized images using the `image_size` argument of `tf.keras.utils.image_dataset_from_directory`. If you want to include the resizing logic in your model as well, you can use the `tf.keras.layers.Resizing` layer.

# %% [markdown]
# ## A basic Keras model
#
# ### Create the model
#
# The Keras [Sequential](https://www.tensorflow.org/guide/keras/sequential_model) model consists of three convolution blocks (`tf.keras.layers.Conv2D`) with a max pooling layer (`tf.keras.layers.MaxPooling2D`) in each of them. There's a fully-connected layer (`tf.keras.layers.Dense`) with 128 units on top of it that is activated by a ReLU activation function (`'relu'`). This model has not been tuned for high accuracy; the goal of this tutorial is to show a standard approach.

# %%
num_classes = len(class_names)
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ### Compile the model
#
# For this tutorial, choose the `tf.keras.optimizers.Adam` optimizer and `tf.keras.losses.SparseCategoricalCrossentropy` loss function. To view training and validation accuracy for each training epoch, pass the `metrics` argument to `Model.compile`.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Model summary
#
# View all the layers of the network using the Keras `Model.summary` method:

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,285 (15.22 MB)
#  Trainable params: 3,989,285 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model

# %% [markdown]
# Train the model for 20 epochs with the Keras `Model.fit` method:

# %%
epochs=20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 12s 65ms/step - accuracy: 0.5449 - loss: 1.3714 - val_accuracy: 0.7063 - val_loss: 0.8023
# Epoch 2/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6898 - loss: 0.8118 - val_accuracy: 0.7172 - val_loss: 0.7755
# Epoch 3/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7136 - loss: 0.7664 - val_accuracy: 0.7104 - val_loss: 0.7556
# Epoch 4/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7337 - loss: 0.7274 - val_accuracy: 0.7145 - val_loss: 0.7765
# Epoch 5/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7317 - loss: 0.7228 - val_accuracy: 0.7363 - val_loss: 0.7406
# Epoch 6/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7684 - loss: 0.6208 - val_accuracy: 0.7404 - val_loss: 0.7276
# Epoch 7/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7663 - loss: 0.6173 - val_accuracy: 0.7309 - val_loss: 0.7095
# Epoch 8/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.7829 - loss: 0.5676 - val_accuracy: 0.7336 - val_loss: 0.7339
# Epoch 9/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7880 - loss: 0.5860 - val_accuracy: 0.7254 - val_loss: 0.7270
# Epoch 10/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8082 - loss: 0.5224 - val_accuracy: 0.7295 - val_loss: 0.7457
# Epoch 11/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8189 - loss: 0.4925 - val_accuracy: 0.7445 - val_loss: 0.7349
# Epoch 12/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8461 - loss: 0.4301 - val_accuracy: 0.7158 - val_loss: 0.8662
# Epoch 13/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8660 - loss: 0.3732 - val_accuracy: 0.7254 - val_loss: 0.8867
# Epoch 14/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8713 - loss: 0.3701 - val_accuracy: 0.7199 - val_loss: 0.8757
# Epoch 15/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8794 - loss: 0.2981 - val_accuracy: 0.7363 - val_loss: 0.8738
# Epoch 16/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9005 - loss: 0.2587 - val_accuracy: 0.6995 - val_loss: 1.0315
# Epoch 17/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9282 - loss: 0.1974 - val_accuracy: 0.7131 - val_loss: 1.1142
# Epoch 18/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9417 - loss: 0.1733 - val_accuracy: 0.7022 - val_loss: 1.1521
# Epoch 19/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9489 - loss: 0.1626 - val_accuracy: 0.7172 - val_loss: 1.1350
# Epoch 20/20
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9579 - loss: 0.1288 - val_accuracy: 0.7227 - val_loss: 1.1409

# %% [markdown]
# ## Visualize training results

# %% [markdown]
# Create plots of the loss and accuracy on the training and validation sets:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 12))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# The plots show that training accuracy and validation accuracy are off by large margins, and the model has achieved only around 60% accuracy on the validation set.
#
# The following tutorial sections show how to inspect what went wrong and try to increase the overall performance of the model.

# %% [markdown]
# ## Overfitting

# %% [markdown]
# In the plots above, the training accuracy is increasing linearly over time, whereas validation accuracy stalls around 60% in the training process. Also, the difference in accuracy between training and validation accuracy is noticeable—a sign of [overfitting](https://www.tensorflow.org/tutorials/keras/overfit_and_underfit).
#
# When there are a small number of training examples, the model sometimes learns from noises or unwanted details from training examples—to an extent that it negatively impacts the performance of the model on new examples. This phenomenon is known as overfitting. It means that the model will have a difficult time generalizing on a new dataset.
#
# There are multiple ways to fight overfitting in the training process. In this tutorial, you'll use *data augmentation* and add *dropout* to your model.

# %% [markdown]
# ## Data augmentation

# %% [markdown]
# Overfitting generally occurs when there are a small number of training examples. [Data augmentation](./data_augmentation.ipynb) takes the approach of generating additional training data from your existing examples by augmenting them using random transformations that yield believable-looking images. This helps expose the model to more aspects of the data and generalize better.
#
# You will implement data augmentation using the following Keras preprocessing layers: `tf.keras.layers.RandomFlip`, `tf.keras.layers.RandomRotation`, and `tf.keras.layers.RandomZoom`. These can be included inside your model like other layers, and run on the GPU.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),  # Small random rotation
    layers.RandomZoom(0.1),  # Random zoom for variability
    layers.RandomContrast(0.2),  # Adjust image contrast randomly
    layers.RandomShear(0.2),  # Apply shear transformations
    layers.RandomTranslation(height_factor=0.1, width_factor=0.1),  # Random translation
  ]
)

# %% [markdown]
# Visualize a few augmented examples by applying data augmentation to the same image several times:

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# You will add data augmentation to your model before training in the next step.

# %%
# Count the number of image files
num_images = len(images)
print(f"Number of images: {num_images}")
# Out:
# Number of images: 32

# %%
# Count the number of augmented_images files
num_augmented_images = len(augmented_images)
print(f"Number of augmented images: {num_augmented_images}")
# Out:
# Number of augmented images: 32

# %% [markdown]
# ## Dropout
#
# Another technique to reduce overfitting is to introduce [dropout](https://developers.google.com/machine-learning/glossary#dropout_regularization){:.external} regularization to the network.
#
# When you apply dropout to a layer, it randomly drops out (by setting the activation to zero) a number of output units from the layer during the training process. Dropout takes a fractional number as its input value, in the form such as 0.1, 0.2, 0.4, etc. This means dropping out 10%, 20% or 40% of the output units randomly from the applied layer.
#
# Create a new neural network with `tf.keras.layers.Dropout` before training it using the augmented images:

# %%
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %% [markdown]
# ## Compile and train the model

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential_1 (Sequential)            │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_2 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ outputs (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,285 (15.22 MB)
#  Trainable params: 3,989,285 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 250
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.5339 - loss: 1.2401 - val_accuracy: 0.5396 - val_loss: 1.2475
# Epoch 2/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6315 - loss: 1.0271 - val_accuracy: 0.5137 - val_loss: 1.1854
# Epoch 3/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6390 - loss: 1.0003 - val_accuracy: 0.6557 - val_loss: 1.0370
# Epoch 4/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.6712 - loss: 0.9279 - val_accuracy: 0.6885 - val_loss: 0.9108
# Epoch 5/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.6762 - loss: 0.9256 - val_accuracy: 0.5055 - val_loss: 1.3467
# Epoch 6/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6731 - loss: 0.9310 - val_accuracy: 0.5697 - val_loss: 1.0962
# Epoch 7/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6567 - loss: 0.9336 - val_accuracy: 0.5738 - val_loss: 1.2744
# Epoch 8/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6695 - loss: 0.8797 - val_accuracy: 0.6448 - val_loss: 0.9984
# Epoch 9/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7015 - loss: 0.8459 - val_accuracy: 0.6189 - val_loss: 1.0304
# Epoch 10/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.6916 - loss: 0.8513 - val_accuracy: 0.6762 - val_loss: 0.9891
# Epoch 11/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.6835 - loss: 0.8512 - val_accuracy: 0.6885 - val_loss: 0.9158
# Epoch 12/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7024 - loss: 0.8212 - val_accuracy: 0.6913 - val_loss: 0.9568
# Epoch 13/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7000 - loss: 0.8055 - val_accuracy: 0.6708 - val_loss: 0.9908
# Epoch 14/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6998 - loss: 0.8330 - val_accuracy: 0.6940 - val_loss: 0.8649
# Epoch 15/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7001 - loss: 0.8157 - val_accuracy: 0.7049 - val_loss: 0.8492
# Epoch 16/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.6955 - loss: 0.8129 - val_accuracy: 0.6339 - val_loss: 1.0469
# Epoch 17/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7014 - loss: 0.8028 - val_accuracy: 0.7036 - val_loss: 0.8130
# Epoch 18/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7070 - loss: 0.8262 - val_accuracy: 0.7036 - val_loss: 0.8821
# Epoch 19/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7095 - loss: 0.7970 - val_accuracy: 0.6940 - val_loss: 0.8292
# Epoch 20/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7031 - loss: 0.7914 - val_accuracy: 0.7049 - val_loss: 0.7912
# Epoch 21/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7095 - loss: 0.7818 - val_accuracy: 0.6954 - val_loss: 0.8457
# Epoch 22/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7231 - loss: 0.7552 - val_accuracy: 0.6694 - val_loss: 0.9024
# Epoch 23/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7152 - loss: 0.7930 - val_accuracy: 0.6926 - val_loss: 0.8517
# Epoch 24/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7102 - loss: 0.7762 - val_accuracy: 0.7104 - val_loss: 0.8257
# Epoch 25/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7217 - loss: 0.7527 - val_accuracy: 0.7309 - val_loss: 0.7713
# Epoch 26/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7060 - loss: 0.7786 - val_accuracy: 0.7131 - val_loss: 0.8337
# Epoch 27/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7105 - loss: 0.7670 - val_accuracy: 0.7158 - val_loss: 0.8031
# Epoch 28/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7090 - loss: 0.7899 - val_accuracy: 0.6967 - val_loss: 0.8694
# Epoch 29/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7183 - loss: 0.7724 - val_accuracy: 0.6940 - val_loss: 0.8125
# Epoch 30/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7060 - loss: 0.7852 - val_accuracy: 0.6954 - val_loss: 0.8555
# Epoch 31/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7042 - loss: 0.8037 - val_accuracy: 0.6940 - val_loss: 0.8406
# Epoch 32/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7130 - loss: 0.7744 - val_accuracy: 0.7063 - val_loss: 0.8335
# Epoch 33/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7241 - loss: 0.7606 - val_accuracy: 0.6831 - val_loss: 0.9913
# Epoch 34/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7295 - loss: 0.7486 - val_accuracy: 0.6749 - val_loss: 0.9381
# Epoch 35/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7427 - loss: 0.6934 - val_accuracy: 0.6967 - val_loss: 0.8520
# Epoch 36/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7361 - loss: 0.7247 - val_accuracy: 0.7090 - val_loss: 0.8042
# Epoch 37/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7212 - loss: 0.7396 - val_accuracy: 0.6981 - val_loss: 0.8649
# Epoch 38/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7271 - loss: 0.7207 - val_accuracy: 0.6735 - val_loss: 0.9578
# Epoch 39/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7349 - loss: 0.7289 - val_accuracy: 0.6940 - val_loss: 0.9125
# Epoch 40/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7371 - loss: 0.6976 - val_accuracy: 0.7172 - val_loss: 0.7911
# Epoch 41/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.7403 - loss: 0.7190 - val_accuracy: 0.7008 - val_loss: 0.8278
# Epoch 42/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7384 - loss: 0.7240 - val_accuracy: 0.6352 - val_loss: 1.0556
# Epoch 43/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7325 - loss: 0.7259 - val_accuracy: 0.7186 - val_loss: 0.9044
# Epoch 44/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7208 - loss: 0.7514 - val_accuracy: 0.7254 - val_loss: 0.8064
# Epoch 45/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7496 - loss: 0.6716 - val_accuracy: 0.7213 - val_loss: 0.7947
# Epoch 46/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7166 - loss: 0.7454 - val_accuracy: 0.7350 - val_loss: 0.7360
# Epoch 47/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7426 - loss: 0.6746 - val_accuracy: 0.6885 - val_loss: 0.9330
# Epoch 48/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7350 - loss: 0.6997 - val_accuracy: 0.7131 - val_loss: 0.8504
# Epoch 49/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7491 - loss: 0.6996 - val_accuracy: 0.7077 - val_loss: 0.8471
# Epoch 50/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7424 - loss: 0.7039 - val_accuracy: 0.7227 - val_loss: 0.7947
# Epoch 51/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7328 - loss: 0.7031 - val_accuracy: 0.7281 - val_loss: 0.7582
# Epoch 52/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7409 - loss: 0.7065 - val_accuracy: 0.6981 - val_loss: 0.8901
# Epoch 53/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7590 - loss: 0.6489 - val_accuracy: 0.7322 - val_loss: 0.7198
# Epoch 54/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7434 - loss: 0.7052 - val_accuracy: 0.7486 - val_loss: 0.7049
# Epoch 55/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7457 - loss: 0.6769 - val_accuracy: 0.7350 - val_loss: 0.6941
# Epoch 56/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7449 - loss: 0.6737 - val_accuracy: 0.7377 - val_loss: 0.7576
# Epoch 57/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7409 - loss: 0.6845 - val_accuracy: 0.7295 - val_loss: 0.7726
# Epoch 58/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7482 - loss: 0.6689 - val_accuracy: 0.7322 - val_loss: 0.7512
# Epoch 59/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7411 - loss: 0.6973 - val_accuracy: 0.7432 - val_loss: 0.7868
# Epoch 60/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7681 - loss: 0.6308 - val_accuracy: 0.6352 - val_loss: 1.1186
# Epoch 61/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7393 - loss: 0.6870 - val_accuracy: 0.7322 - val_loss: 0.7472
# Epoch 62/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7536 - loss: 0.6609 - val_accuracy: 0.7391 - val_loss: 0.7084
# Epoch 63/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7486 - loss: 0.6613 - val_accuracy: 0.7158 - val_loss: 0.7733
# Epoch 64/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7489 - loss: 0.6607 - val_accuracy: 0.6995 - val_loss: 0.8560
# Epoch 65/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7425 - loss: 0.6747 - val_accuracy: 0.7500 - val_loss: 0.7010
# Epoch 66/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7440 - loss: 0.6957 - val_accuracy: 0.7172 - val_loss: 0.7721
# Epoch 67/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.7468 - loss: 0.6747 - val_accuracy: 0.7473 - val_loss: 0.7002
# Epoch 68/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7355 - loss: 0.6746 - val_accuracy: 0.7486 - val_loss: 0.6600
# Epoch 69/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7567 - loss: 0.6429 - val_accuracy: 0.7404 - val_loss: 0.6941
# Epoch 70/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7468 - loss: 0.6626 - val_accuracy: 0.7445 - val_loss: 0.6748
# Epoch 71/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7764 - loss: 0.6286 - val_accuracy: 0.7309 - val_loss: 0.7247
# Epoch 72/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7509 - loss: 0.6563 - val_accuracy: 0.7254 - val_loss: 0.7466
# Epoch 73/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7523 - loss: 0.6619 - val_accuracy: 0.7609 - val_loss: 0.6870
# Epoch 74/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7582 - loss: 0.6387 - val_accuracy: 0.7486 - val_loss: 0.6797
# Epoch 75/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7513 - loss: 0.6432 - val_accuracy: 0.7309 - val_loss: 0.6812
# Epoch 76/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7548 - loss: 0.6517 - val_accuracy: 0.7254 - val_loss: 0.7573
# Epoch 77/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7544 - loss: 0.6487 - val_accuracy: 0.7336 - val_loss: 0.7561
# Epoch 78/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7713 - loss: 0.5978 - val_accuracy: 0.7391 - val_loss: 0.6840
# Epoch 79/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7583 - loss: 0.6236 - val_accuracy: 0.7541 - val_loss: 0.6606
# Epoch 80/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7597 - loss: 0.6355 - val_accuracy: 0.7199 - val_loss: 0.8206
# Epoch 81/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7671 - loss: 0.6387 - val_accuracy: 0.7486 - val_loss: 0.6807
# Epoch 82/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7729 - loss: 0.6063 - val_accuracy: 0.7473 - val_loss: 0.7202
# Epoch 83/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7545 - loss: 0.6507 - val_accuracy: 0.7391 - val_loss: 0.7113
# Epoch 84/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7647 - loss: 0.6227 - val_accuracy: 0.7391 - val_loss: 0.7057
# Epoch 85/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7710 - loss: 0.6159 - val_accuracy: 0.7309 - val_loss: 0.6751
# Epoch 86/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.7592 - loss: 0.6223 - val_accuracy: 0.7363 - val_loss: 0.7895
# Epoch 87/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7519 - loss: 0.6294 - val_accuracy: 0.7363 - val_loss: 0.6969
# Epoch 88/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7669 - loss: 0.6346 - val_accuracy: 0.7459 - val_loss: 0.6612
# Epoch 89/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.7665 - loss: 0.6278 - val_accuracy: 0.7404 - val_loss: 0.7091
# Epoch 90/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7727 - loss: 0.5970 - val_accuracy: 0.7555 - val_loss: 0.6756
# Epoch 91/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7763 - loss: 0.5831 - val_accuracy: 0.7418 - val_loss: 0.6815
# Epoch 92/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7650 - loss: 0.6036 - val_accuracy: 0.7418 - val_loss: 0.6742
# Epoch 93/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7709 - loss: 0.6097 - val_accuracy: 0.7404 - val_loss: 0.6838
# Epoch 94/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7626 - loss: 0.5957 - val_accuracy: 0.7527 - val_loss: 0.7279
# Epoch 95/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7673 - loss: 0.6198 - val_accuracy: 0.7350 - val_loss: 0.6945
# Epoch 96/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7468 - loss: 0.6288 - val_accuracy: 0.7623 - val_loss: 0.6627
# Epoch 97/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7675 - loss: 0.5999 - val_accuracy: 0.7541 - val_loss: 0.6818
# Epoch 98/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7621 - loss: 0.6231 - val_accuracy: 0.7541 - val_loss: 0.6739
# Epoch 99/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7806 - loss: 0.5756 - val_accuracy: 0.7350 - val_loss: 0.6997
# Epoch 100/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7620 - loss: 0.6260 - val_accuracy: 0.7514 - val_loss: 0.6694
# Epoch 101/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7548 - loss: 0.6441 - val_accuracy: 0.7309 - val_loss: 0.7484
# Epoch 102/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7738 - loss: 0.6045 - val_accuracy: 0.7609 - val_loss: 0.6576
# Epoch 103/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7696 - loss: 0.5986 - val_accuracy: 0.7514 - val_loss: 0.6777
# Epoch 104/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7658 - loss: 0.6267 - val_accuracy: 0.7650 - val_loss: 0.6742
# Epoch 105/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7673 - loss: 0.5990 - val_accuracy: 0.7650 - val_loss: 0.6721
# Epoch 106/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7748 - loss: 0.5926 - val_accuracy: 0.7473 - val_loss: 0.6717
# Epoch 107/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7560 - loss: 0.6136 - val_accuracy: 0.7473 - val_loss: 0.7467
# Epoch 108/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7628 - loss: 0.6136 - val_accuracy: 0.7391 - val_loss: 0.6649
# Epoch 109/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7899 - loss: 0.5673 - val_accuracy: 0.7486 - val_loss: 0.6885
# Epoch 110/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7729 - loss: 0.5812 - val_accuracy: 0.7473 - val_loss: 0.7011
# Epoch 111/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7684 - loss: 0.5998 - val_accuracy: 0.7350 - val_loss: 0.6925
# Epoch 112/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7690 - loss: 0.6065 - val_accuracy: 0.7582 - val_loss: 0.7039
# Epoch 113/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7782 - loss: 0.5725 - val_accuracy: 0.7199 - val_loss: 0.7709
# Epoch 114/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7779 - loss: 0.6017 - val_accuracy: 0.7582 - val_loss: 0.6568
# Epoch 115/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7831 - loss: 0.5605 - val_accuracy: 0.7596 - val_loss: 0.6643
# Epoch 116/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7732 - loss: 0.5926 - val_accuracy: 0.7363 - val_loss: 0.6736
# Epoch 117/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7616 - loss: 0.6041 - val_accuracy: 0.7555 - val_loss: 0.6910
# Epoch 118/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7842 - loss: 0.5709 - val_accuracy: 0.7268 - val_loss: 0.6962
# Epoch 119/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7778 - loss: 0.5784 - val_accuracy: 0.7596 - val_loss: 0.6429
# Epoch 120/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7720 - loss: 0.5932 - val_accuracy: 0.7514 - val_loss: 0.6889
# Epoch 121/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7566 - loss: 0.6469 - val_accuracy: 0.7541 - val_loss: 0.6575
# Epoch 122/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7765 - loss: 0.5995 - val_accuracy: 0.7609 - val_loss: 0.6470
# Epoch 123/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7864 - loss: 0.5611 - val_accuracy: 0.7486 - val_loss: 0.7114
# Epoch 124/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7837 - loss: 0.5817 - val_accuracy: 0.7473 - val_loss: 0.6741
# Epoch 125/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7766 - loss: 0.5979 - val_accuracy: 0.7609 - val_loss: 0.6551
# Epoch 126/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7762 - loss: 0.5837 - val_accuracy: 0.7432 - val_loss: 0.7179
# Epoch 127/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7602 - loss: 0.6291 - val_accuracy: 0.7459 - val_loss: 0.7362
# Epoch 128/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7635 - loss: 0.6241 - val_accuracy: 0.7541 - val_loss: 0.6802
# Epoch 129/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7666 - loss: 0.6018 - val_accuracy: 0.7350 - val_loss: 0.7863
# Epoch 130/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7796 - loss: 0.5718 - val_accuracy: 0.7541 - val_loss: 0.6734
# Epoch 131/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7729 - loss: 0.5839 - val_accuracy: 0.7582 - val_loss: 0.6407
# Epoch 132/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7793 - loss: 0.5810 - val_accuracy: 0.7664 - val_loss: 0.6484
# Epoch 133/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7637 - loss: 0.6131 - val_accuracy: 0.7459 - val_loss: 0.7563
# Epoch 134/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7907 - loss: 0.5415 - val_accuracy: 0.7596 - val_loss: 0.7015
# Epoch 135/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7758 - loss: 0.5654 - val_accuracy: 0.7568 - val_loss: 0.6645
# Epoch 136/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7704 - loss: 0.5919 - val_accuracy: 0.7623 - val_loss: 0.7118
# Epoch 137/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7955 - loss: 0.5606 - val_accuracy: 0.7582 - val_loss: 0.7227
# Epoch 138/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7845 - loss: 0.5844 - val_accuracy: 0.7596 - val_loss: 0.6530
# Epoch 139/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7874 - loss: 0.5660 - val_accuracy: 0.7514 - val_loss: 0.6880
# Epoch 140/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7870 - loss: 0.5751 - val_accuracy: 0.7555 - val_loss: 0.6658
# Epoch 141/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7806 - loss: 0.5618 - val_accuracy: 0.7568 - val_loss: 0.6821
# Epoch 142/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7677 - loss: 0.5982 - val_accuracy: 0.7555 - val_loss: 0.6613
# Epoch 143/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7793 - loss: 0.5656 - val_accuracy: 0.7445 - val_loss: 0.6706
# Epoch 144/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7930 - loss: 0.5477 - val_accuracy: 0.7473 - val_loss: 0.6855
# Epoch 145/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7861 - loss: 0.5554 - val_accuracy: 0.7678 - val_loss: 0.6708
# Epoch 146/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7738 - loss: 0.5717 - val_accuracy: 0.7555 - val_loss: 0.6554
# Epoch 147/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7765 - loss: 0.5761 - val_accuracy: 0.7582 - val_loss: 0.6740
# Epoch 148/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7851 - loss: 0.5419 - val_accuracy: 0.7500 - val_loss: 0.6900
# Epoch 149/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7824 - loss: 0.5617 - val_accuracy: 0.7117 - val_loss: 0.8868
# Epoch 150/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7854 - loss: 0.5722 - val_accuracy: 0.7227 - val_loss: 0.7944
# Epoch 151/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7829 - loss: 0.5918 - val_accuracy: 0.7281 - val_loss: 0.8713
# Epoch 152/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7801 - loss: 0.5787 - val_accuracy: 0.7609 - val_loss: 0.6555
# Epoch 153/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7795 - loss: 0.5700 - val_accuracy: 0.7568 - val_loss: 0.6729
# Epoch 154/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7747 - loss: 0.5656 - val_accuracy: 0.7582 - val_loss: 0.6466
# Epoch 155/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7831 - loss: 0.5787 - val_accuracy: 0.7514 - val_loss: 0.6855
# Epoch 156/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.7734 - loss: 0.5936 - val_accuracy: 0.7486 - val_loss: 0.6919
# Epoch 157/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.7858 - loss: 0.5397 - val_accuracy: 0.7363 - val_loss: 0.7388
# Epoch 158/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7774 - loss: 0.5609 - val_accuracy: 0.7254 - val_loss: 0.6803
# Epoch 159/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7717 - loss: 0.5825 - val_accuracy: 0.7309 - val_loss: 0.6969
# Epoch 160/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.7781 - loss: 0.5808 - val_accuracy: 0.7473 - val_loss: 0.7112
# Epoch 161/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7678 - loss: 0.5653 - val_accuracy: 0.7582 - val_loss: 0.6702
# Epoch 162/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7998 - loss: 0.5437 - val_accuracy: 0.7582 - val_loss: 0.6746
# Epoch 163/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.7894 - loss: 0.5346 - val_accuracy: 0.7609 - val_loss: 0.6475
# Epoch 164/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7895 - loss: 0.5571 - val_accuracy: 0.7363 - val_loss: 0.6801
# Epoch 165/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7863 - loss: 0.5607 - val_accuracy: 0.7555 - val_loss: 0.6733
# Epoch 166/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7789 - loss: 0.5670 - val_accuracy: 0.7486 - val_loss: 0.6958
# Epoch 167/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7776 - loss: 0.5809 - val_accuracy: 0.7418 - val_loss: 0.7086
# Epoch 168/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8022 - loss: 0.5284 - val_accuracy: 0.7459 - val_loss: 0.6431
# Epoch 169/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7835 - loss: 0.5650 - val_accuracy: 0.7514 - val_loss: 0.7167
# Epoch 170/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7748 - loss: 0.5641 - val_accuracy: 0.7541 - val_loss: 0.6673
# Epoch 171/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7691 - loss: 0.5794 - val_accuracy: 0.7541 - val_loss: 0.6972
# Epoch 172/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7924 - loss: 0.5652 - val_accuracy: 0.7363 - val_loss: 0.7349
# Epoch 173/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7958 - loss: 0.5290 - val_accuracy: 0.7637 - val_loss: 0.6373
# Epoch 174/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7827 - loss: 0.5489 - val_accuracy: 0.7391 - val_loss: 0.7561
# Epoch 175/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7982 - loss: 0.5474 - val_accuracy: 0.7596 - val_loss: 0.6689
# Epoch 176/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7880 - loss: 0.5516 - val_accuracy: 0.7363 - val_loss: 0.7487
# Epoch 177/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7978 - loss: 0.5466 - val_accuracy: 0.7623 - val_loss: 0.6401
# Epoch 178/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7783 - loss: 0.5619 - val_accuracy: 0.7500 - val_loss: 0.6941
# Epoch 179/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7820 - loss: 0.5618 - val_accuracy: 0.7541 - val_loss: 0.6525
# Epoch 180/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8053 - loss: 0.5141 - val_accuracy: 0.7473 - val_loss: 0.6552
# Epoch 181/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7888 - loss: 0.5446 - val_accuracy: 0.7637 - val_loss: 0.6557
# Epoch 182/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7924 - loss: 0.5274 - val_accuracy: 0.7568 - val_loss: 0.6468
# Epoch 183/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7958 - loss: 0.5290 - val_accuracy: 0.7637 - val_loss: 0.6945
# Epoch 184/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7895 - loss: 0.5678 - val_accuracy: 0.7527 - val_loss: 0.6741
# Epoch 185/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7856 - loss: 0.5504 - val_accuracy: 0.7254 - val_loss: 0.8169
# Epoch 186/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7900 - loss: 0.5589 - val_accuracy: 0.7637 - val_loss: 0.6570
# Epoch 187/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7802 - loss: 0.5623 - val_accuracy: 0.7500 - val_loss: 0.7597
# Epoch 188/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8056 - loss: 0.5282 - val_accuracy: 0.7514 - val_loss: 0.6748
# Epoch 189/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7892 - loss: 0.5700 - val_accuracy: 0.7391 - val_loss: 0.7162
# Epoch 190/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.7784 - loss: 0.5805 - val_accuracy: 0.7377 - val_loss: 0.6932
# Epoch 191/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7872 - loss: 0.5575 - val_accuracy: 0.7459 - val_loss: 0.7070
# Epoch 192/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7794 - loss: 0.5581 - val_accuracy: 0.7391 - val_loss: 0.7046
# Epoch 193/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.7794 - loss: 0.5648 - val_accuracy: 0.7555 - val_loss: 0.6920
# Epoch 194/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7914 - loss: 0.5574 - val_accuracy: 0.7404 - val_loss: 0.7074
# Epoch 195/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7973 - loss: 0.5386 - val_accuracy: 0.7473 - val_loss: 0.7061
# Epoch 196/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.7897 - loss: 0.5374 - val_accuracy: 0.7445 - val_loss: 0.7088
# Epoch 197/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8025 - loss: 0.5124 - val_accuracy: 0.7254 - val_loss: 0.7441
# Epoch 198/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7935 - loss: 0.5672 - val_accuracy: 0.7582 - val_loss: 0.7202
# Epoch 199/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7764 - loss: 0.5735 - val_accuracy: 0.7650 - val_loss: 0.6694
# Epoch 200/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7810 - loss: 0.5649 - val_accuracy: 0.7609 - val_loss: 0.7777
# Epoch 201/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7892 - loss: 0.5416 - val_accuracy: 0.7609 - val_loss: 0.7362
# Epoch 202/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7956 - loss: 0.5451 - val_accuracy: 0.7336 - val_loss: 0.7276
# Epoch 203/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8020 - loss: 0.5154 - val_accuracy: 0.7486 - val_loss: 0.7010
# Epoch 204/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8000 - loss: 0.5167 - val_accuracy: 0.7582 - val_loss: 0.6762
# Epoch 205/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7800 - loss: 0.5439 - val_accuracy: 0.7514 - val_loss: 0.7086
# Epoch 206/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7933 - loss: 0.5256 - val_accuracy: 0.7514 - val_loss: 0.6967
# Epoch 207/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8066 - loss: 0.4973 - val_accuracy: 0.7172 - val_loss: 0.8060
# Epoch 208/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.7965 - loss: 0.5284 - val_accuracy: 0.7459 - val_loss: 0.7028
# Epoch 209/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8048 - loss: 0.5098 - val_accuracy: 0.7363 - val_loss: 0.7841
# Epoch 210/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8153 - loss: 0.4997 - val_accuracy: 0.7254 - val_loss: 0.8076
# Epoch 211/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.7978 - loss: 0.5295 - val_accuracy: 0.7473 - val_loss: 0.7323
# Epoch 212/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8104 - loss: 0.5043 - val_accuracy: 0.7459 - val_loss: 0.7284
# Epoch 213/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8005 - loss: 0.5310 - val_accuracy: 0.7404 - val_loss: 0.7124
# Epoch 214/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7922 - loss: 0.5424 - val_accuracy: 0.7541 - val_loss: 0.7320
# Epoch 215/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8017 - loss: 0.5138 - val_accuracy: 0.7732 - val_loss: 0.6613
# Epoch 216/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8023 - loss: 0.5089 - val_accuracy: 0.7254 - val_loss: 0.7791
# Epoch 217/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8049 - loss: 0.4975 - val_accuracy: 0.7295 - val_loss: 0.7181
# Epoch 218/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.7843 - loss: 0.5587 - val_accuracy: 0.7609 - val_loss: 0.6762
# Epoch 219/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.7914 - loss: 0.5402 - val_accuracy: 0.7391 - val_loss: 0.7378
# Epoch 220/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8057 - loss: 0.5056 - val_accuracy: 0.7213 - val_loss: 0.7229
# Epoch 221/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7846 - loss: 0.5550 - val_accuracy: 0.7719 - val_loss: 0.7228
# Epoch 222/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8041 - loss: 0.5093 - val_accuracy: 0.7609 - val_loss: 0.7132
# Epoch 223/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7831 - loss: 0.5778 - val_accuracy: 0.7582 - val_loss: 0.6774
# Epoch 224/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7988 - loss: 0.5181 - val_accuracy: 0.7623 - val_loss: 0.6682
# Epoch 225/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7958 - loss: 0.5154 - val_accuracy: 0.7582 - val_loss: 0.6807
# Epoch 226/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7948 - loss: 0.5290 - val_accuracy: 0.7391 - val_loss: 0.7371
# Epoch 227/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7938 - loss: 0.5109 - val_accuracy: 0.7527 - val_loss: 0.7242
# Epoch 228/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.7901 - loss: 0.5508 - val_accuracy: 0.7473 - val_loss: 0.7526
# Epoch 229/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7921 - loss: 0.5458 - val_accuracy: 0.7555 - val_loss: 0.6584
# Epoch 230/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7988 - loss: 0.5210 - val_accuracy: 0.7637 - val_loss: 0.6899
# Epoch 231/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7969 - loss: 0.5299 - val_accuracy: 0.7582 - val_loss: 0.6855
# Epoch 232/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7918 - loss: 0.5505 - val_accuracy: 0.7391 - val_loss: 0.8283
# Epoch 233/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7827 - loss: 0.5459 - val_accuracy: 0.7473 - val_loss: 0.7494
# Epoch 234/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8053 - loss: 0.5100 - val_accuracy: 0.7404 - val_loss: 0.7188
# Epoch 235/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8044 - loss: 0.4893 - val_accuracy: 0.7418 - val_loss: 0.7851
# Epoch 236/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8041 - loss: 0.5155 - val_accuracy: 0.7582 - val_loss: 0.6937
# Epoch 237/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7952 - loss: 0.5304 - val_accuracy: 0.7623 - val_loss: 0.7106
# Epoch 238/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7964 - loss: 0.5177 - val_accuracy: 0.7582 - val_loss: 0.7466
# Epoch 239/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8006 - loss: 0.5056 - val_accuracy: 0.7527 - val_loss: 0.6868
# Epoch 240/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7915 - loss: 0.5275 - val_accuracy: 0.7486 - val_loss: 0.7328
# Epoch 241/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7931 - loss: 0.5385 - val_accuracy: 0.7555 - val_loss: 0.7120
# Epoch 242/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8054 - loss: 0.4862 - val_accuracy: 0.7199 - val_loss: 0.8072
# Epoch 243/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7986 - loss: 0.5359 - val_accuracy: 0.7350 - val_loss: 0.8175
# Epoch 244/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8082 - loss: 0.5045 - val_accuracy: 0.7623 - val_loss: 0.6492
# Epoch 245/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8130 - loss: 0.5033 - val_accuracy: 0.7391 - val_loss: 0.8136
# Epoch 246/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7944 - loss: 0.5448 - val_accuracy: 0.7500 - val_loss: 0.6977
# Epoch 247/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8197 - loss: 0.5044 - val_accuracy: 0.7541 - val_loss: 0.7435
# Epoch 248/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7969 - loss: 0.5349 - val_accuracy: 0.7432 - val_loss: 0.7842
# Epoch 249/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8104 - loss: 0.5098 - val_accuracy: 0.7527 - val_loss: 0.7302
# Epoch 250/250
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.7806 - loss: 0.5366 - val_accuracy: 0.7500 - val_loss: 0.7270

# %% [markdown]
# ## Visualize training results
#
# After applying data augmentation and `tf.keras.layers.Dropout`, there is less overfitting than before, and training and validation accuracy are closer aligned:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
epochs = 500
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8636 - loss: 0.3672 - val_accuracy: 0.7609 - val_loss: 0.9309
# Epoch 2/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8436 - loss: 0.4168 - val_accuracy: 0.7541 - val_loss: 0.9476
# Epoch 3/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 37ms/step - accuracy: 0.8422 - loss: 0.4127 - val_accuracy: 0.7527 - val_loss: 0.8578
# Epoch 4/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8617 - loss: 0.3759 - val_accuracy: 0.7596 - val_loss: 0.9424
# Epoch 5/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8375 - loss: 0.3903 - val_accuracy: 0.7377 - val_loss: 1.2547
# Epoch 6/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8563 - loss: 0.4070 - val_accuracy: 0.7596 - val_loss: 1.0288
# Epoch 7/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8670 - loss: 0.3710 - val_accuracy: 0.7363 - val_loss: 0.9981
# Epoch 8/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8531 - loss: 0.4018 - val_accuracy: 0.7486 - val_loss: 0.9074
# Epoch 9/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8398 - loss: 0.4202 - val_accuracy: 0.7609 - val_loss: 1.0228
# Epoch 10/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8502 - loss: 0.3872 - val_accuracy: 0.7555 - val_loss: 1.0026
# Epoch 11/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8396 - loss: 0.3968 - val_accuracy: 0.7404 - val_loss: 0.8979
# Epoch 12/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8443 - loss: 0.4196 - val_accuracy: 0.7445 - val_loss: 0.9549
# Epoch 13/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8459 - loss: 0.4077 - val_accuracy: 0.7363 - val_loss: 1.0709
# Epoch 14/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8486 - loss: 0.3811 - val_accuracy: 0.7555 - val_loss: 0.8791
# Epoch 15/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8362 - loss: 0.4225 - val_accuracy: 0.7486 - val_loss: 0.9961
# Epoch 16/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8428 - loss: 0.4108 - val_accuracy: 0.7732 - val_loss: 0.9708
# Epoch 17/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8517 - loss: 0.3855 - val_accuracy: 0.7541 - val_loss: 0.9080
# Epoch 18/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8461 - loss: 0.3910 - val_accuracy: 0.7568 - val_loss: 0.9302
# Epoch 19/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8398 - loss: 0.4071 - val_accuracy: 0.7432 - val_loss: 0.9795
# Epoch 20/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8563 - loss: 0.4055 - val_accuracy: 0.7541 - val_loss: 0.9011
# Epoch 21/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8388 - loss: 0.4231 - val_accuracy: 0.7459 - val_loss: 1.0650
# Epoch 22/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8394 - loss: 0.3897 - val_accuracy: 0.7473 - val_loss: 1.0117
# Epoch 23/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8506 - loss: 0.4159 - val_accuracy: 0.7391 - val_loss: 0.9634
# Epoch 24/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.8503 - loss: 0.3974 - val_accuracy: 0.7268 - val_loss: 1.0068
# Epoch 25/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8496 - loss: 0.3971 - val_accuracy: 0.7650 - val_loss: 0.9365
# Epoch 26/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8486 - loss: 0.3821 - val_accuracy: 0.7336 - val_loss: 0.8788
# Epoch 27/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8550 - loss: 0.3750 - val_accuracy: 0.7760 - val_loss: 0.9896
# Epoch 28/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8520 - loss: 0.4054 - val_accuracy: 0.7691 - val_loss: 0.9010
# Epoch 29/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8499 - loss: 0.3851 - val_accuracy: 0.7637 - val_loss: 0.8978
# Epoch 30/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8463 - loss: 0.3967 - val_accuracy: 0.7254 - val_loss: 1.1882
# Epoch 31/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8388 - loss: 0.4174 - val_accuracy: 0.7500 - val_loss: 0.9759
# Epoch 32/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8548 - loss: 0.3789 - val_accuracy: 0.7568 - val_loss: 0.9060
# Epoch 33/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8473 - loss: 0.4173 - val_accuracy: 0.7486 - val_loss: 0.9463
# Epoch 34/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8476 - loss: 0.3852 - val_accuracy: 0.7336 - val_loss: 1.0195
# Epoch 35/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8436 - loss: 0.3971 - val_accuracy: 0.7377 - val_loss: 1.0566
# Epoch 36/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8469 - loss: 0.3958 - val_accuracy: 0.7637 - val_loss: 0.9956
# Epoch 37/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8486 - loss: 0.3869 - val_accuracy: 0.7568 - val_loss: 0.9334
# Epoch 38/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8650 - loss: 0.3579 - val_accuracy: 0.7582 - val_loss: 0.9331
# Epoch 39/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8618 - loss: 0.3577 - val_accuracy: 0.7609 - val_loss: 1.0333
# Epoch 40/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8529 - loss: 0.3887 - val_accuracy: 0.7650 - val_loss: 0.8734
# Epoch 41/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8410 - loss: 0.4128 - val_accuracy: 0.7637 - val_loss: 0.9542
# Epoch 42/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8530 - loss: 0.3933 - val_accuracy: 0.7391 - val_loss: 0.9691
# Epoch 43/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8563 - loss: 0.3734 - val_accuracy: 0.7650 - val_loss: 0.9619
# Epoch 44/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8581 - loss: 0.3769 - val_accuracy: 0.7336 - val_loss: 0.9833
# Epoch 45/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8511 - loss: 0.4191 - val_accuracy: 0.7445 - val_loss: 0.9917
# Epoch 46/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8570 - loss: 0.3821 - val_accuracy: 0.7486 - val_loss: 0.9818
# Epoch 47/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8422 - loss: 0.3931 - val_accuracy: 0.7609 - val_loss: 0.9196
# Epoch 48/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8494 - loss: 0.4007 - val_accuracy: 0.7418 - val_loss: 1.0699
# Epoch 49/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8602 - loss: 0.3682 - val_accuracy: 0.7705 - val_loss: 0.9746
# Epoch 50/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8479 - loss: 0.3966 - val_accuracy: 0.7336 - val_loss: 0.9591
# Epoch 51/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8387 - loss: 0.4048 - val_accuracy: 0.7637 - val_loss: 0.9459
# Epoch 52/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8540 - loss: 0.3929 - val_accuracy: 0.7350 - val_loss: 0.9381
# Epoch 53/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8514 - loss: 0.3947 - val_accuracy: 0.7500 - val_loss: 0.9357
# Epoch 54/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8380 - loss: 0.4017 - val_accuracy: 0.7555 - val_loss: 0.9855
# Epoch 55/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8419 - loss: 0.3953 - val_accuracy: 0.7691 - val_loss: 0.9494
# Epoch 56/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8679 - loss: 0.3560 - val_accuracy: 0.7732 - val_loss: 0.9563
# Epoch 57/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8551 - loss: 0.3670 - val_accuracy: 0.7664 - val_loss: 0.9193
# Epoch 58/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8630 - loss: 0.3611 - val_accuracy: 0.7596 - val_loss: 0.8952
# Epoch 59/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8387 - loss: 0.4166 - val_accuracy: 0.7623 - val_loss: 0.8915
# Epoch 60/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8538 - loss: 0.3688 - val_accuracy: 0.7623 - val_loss: 0.9022
# Epoch 61/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8411 - loss: 0.3944 - val_accuracy: 0.7623 - val_loss: 0.8646
# Epoch 62/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8521 - loss: 0.3892 - val_accuracy: 0.7555 - val_loss: 0.9436
# Epoch 63/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8458 - loss: 0.3765 - val_accuracy: 0.7500 - val_loss: 0.9592
# Epoch 64/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8528 - loss: 0.3811 - val_accuracy: 0.7691 - val_loss: 1.0722
# Epoch 65/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8681 - loss: 0.3504 - val_accuracy: 0.7555 - val_loss: 1.1661
# Epoch 66/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8431 - loss: 0.4278 - val_accuracy: 0.7555 - val_loss: 0.9584
# Epoch 67/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8351 - loss: 0.4063 - val_accuracy: 0.7637 - val_loss: 0.8994
# Epoch 68/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8475 - loss: 0.3933 - val_accuracy: 0.7582 - val_loss: 1.0001
# Epoch 69/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8466 - loss: 0.3917 - val_accuracy: 0.7432 - val_loss: 1.0021
# Epoch 70/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8731 - loss: 0.3291 - val_accuracy: 0.7609 - val_loss: 0.9977
# Epoch 71/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8308 - loss: 0.4315 - val_accuracy: 0.7678 - val_loss: 0.8816
# Epoch 72/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8559 - loss: 0.3686 - val_accuracy: 0.7322 - val_loss: 1.0529
# Epoch 73/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8441 - loss: 0.3884 - val_accuracy: 0.7486 - val_loss: 1.0979
# Epoch 74/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8381 - loss: 0.3957 - val_accuracy: 0.7555 - val_loss: 0.9205
# Epoch 75/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8449 - loss: 0.4078 - val_accuracy: 0.7568 - val_loss: 1.0678
# Epoch 76/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8509 - loss: 0.3995 - val_accuracy: 0.7582 - val_loss: 1.0169
# Epoch 77/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8517 - loss: 0.3889 - val_accuracy: 0.7691 - val_loss: 1.0298
# Epoch 78/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.8597 - loss: 0.3989 - val_accuracy: 0.7582 - val_loss: 0.9188
# Epoch 79/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8566 - loss: 0.3804 - val_accuracy: 0.7363 - val_loss: 1.0061
# Epoch 80/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8328 - loss: 0.4173 - val_accuracy: 0.7596 - val_loss: 1.0153
# Epoch 81/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8433 - loss: 0.3914 - val_accuracy: 0.7555 - val_loss: 0.9061
# Epoch 82/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8287 - loss: 0.4606 - val_accuracy: 0.7623 - val_loss: 0.9315
# Epoch 83/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8563 - loss: 0.3546 - val_accuracy: 0.7486 - val_loss: 1.0508
# Epoch 84/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8537 - loss: 0.3955 - val_accuracy: 0.7609 - val_loss: 1.0392
# Epoch 85/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8668 - loss: 0.3535 - val_accuracy: 0.7459 - val_loss: 1.1068
# Epoch 86/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8435 - loss: 0.4005 - val_accuracy: 0.7637 - val_loss: 0.9496
# Epoch 87/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8695 - loss: 0.3413 - val_accuracy: 0.7363 - val_loss: 1.0745
# Epoch 88/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8425 - loss: 0.3906 - val_accuracy: 0.7473 - val_loss: 0.9747
# Epoch 89/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8540 - loss: 0.3784 - val_accuracy: 0.7473 - val_loss: 0.9672
# Epoch 90/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8463 - loss: 0.3936 - val_accuracy: 0.7691 - val_loss: 1.0069
# Epoch 91/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8395 - loss: 0.4039 - val_accuracy: 0.7500 - val_loss: 0.9614
# Epoch 92/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8498 - loss: 0.3853 - val_accuracy: 0.7691 - val_loss: 0.9663
# Epoch 93/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8626 - loss: 0.3525 - val_accuracy: 0.7582 - val_loss: 1.0304
# Epoch 94/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8579 - loss: 0.3701 - val_accuracy: 0.7418 - val_loss: 1.0413
# Epoch 95/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8634 - loss: 0.3542 - val_accuracy: 0.7541 - val_loss: 1.0422
# Epoch 96/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8511 - loss: 0.3845 - val_accuracy: 0.7650 - val_loss: 1.0437
# Epoch 97/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8557 - loss: 0.3760 - val_accuracy: 0.7527 - val_loss: 1.1343
# Epoch 98/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8217 - loss: 0.4531 - val_accuracy: 0.7637 - val_loss: 0.9404
# Epoch 99/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8565 - loss: 0.3909 - val_accuracy: 0.7596 - val_loss: 1.0871
# Epoch 100/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8664 - loss: 0.3576 - val_accuracy: 0.7432 - val_loss: 0.9932
# Epoch 101/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8634 - loss: 0.3527 - val_accuracy: 0.7705 - val_loss: 0.9624
# Epoch 102/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8581 - loss: 0.3700 - val_accuracy: 0.7541 - val_loss: 1.0196
# Epoch 103/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8437 - loss: 0.4077 - val_accuracy: 0.7500 - val_loss: 0.9984
# Epoch 104/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8559 - loss: 0.3916 - val_accuracy: 0.7568 - val_loss: 1.0270
# Epoch 105/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8500 - loss: 0.3961 - val_accuracy: 0.7527 - val_loss: 0.9859
# Epoch 106/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8656 - loss: 0.3650 - val_accuracy: 0.7486 - val_loss: 1.0758
# Epoch 107/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8598 - loss: 0.3572 - val_accuracy: 0.7582 - val_loss: 1.0642
# Epoch 108/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8546 - loss: 0.3740 - val_accuracy: 0.7623 - val_loss: 0.9279
# Epoch 109/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8657 - loss: 0.3690 - val_accuracy: 0.7623 - val_loss: 0.9931
# Epoch 110/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8567 - loss: 0.3737 - val_accuracy: 0.7541 - val_loss: 1.0284
# Epoch 111/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8580 - loss: 0.3909 - val_accuracy: 0.7609 - val_loss: 1.0683
# Epoch 112/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8720 - loss: 0.3650 - val_accuracy: 0.7596 - val_loss: 1.0291
# Epoch 113/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8631 - loss: 0.3759 - val_accuracy: 0.7609 - val_loss: 0.9284
# Epoch 114/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8530 - loss: 0.3772 - val_accuracy: 0.7541 - val_loss: 1.0298
# Epoch 115/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8540 - loss: 0.3752 - val_accuracy: 0.7473 - val_loss: 0.9608
# Epoch 116/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8537 - loss: 0.3638 - val_accuracy: 0.7650 - val_loss: 0.9956
# Epoch 117/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8549 - loss: 0.3730 - val_accuracy: 0.7691 - val_loss: 1.0393
# Epoch 118/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8528 - loss: 0.3821 - val_accuracy: 0.7609 - val_loss: 0.9929
# Epoch 119/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8732 - loss: 0.3366 - val_accuracy: 0.7582 - val_loss: 0.9340
# Epoch 120/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8557 - loss: 0.3924 - val_accuracy: 0.7514 - val_loss: 0.9724
# Epoch 121/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8382 - loss: 0.4343 - val_accuracy: 0.7596 - val_loss: 1.0003
# Epoch 122/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8553 - loss: 0.3704 - val_accuracy: 0.7541 - val_loss: 1.0792
# Epoch 123/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8346 - loss: 0.4279 - val_accuracy: 0.7555 - val_loss: 1.0035
# Epoch 124/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8704 - loss: 0.3423 - val_accuracy: 0.7637 - val_loss: 1.0146
# Epoch 125/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8696 - loss: 0.3478 - val_accuracy: 0.7541 - val_loss: 1.1630
# Epoch 126/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8672 - loss: 0.3546 - val_accuracy: 0.7582 - val_loss: 0.9162
# Epoch 127/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8551 - loss: 0.3566 - val_accuracy: 0.7473 - val_loss: 1.0157
# Epoch 128/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8520 - loss: 0.3698 - val_accuracy: 0.7596 - val_loss: 1.0385
# Epoch 129/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8647 - loss: 0.3686 - val_accuracy: 0.7336 - val_loss: 1.1826
# Epoch 130/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8683 - loss: 0.3421 - val_accuracy: 0.7650 - val_loss: 1.0030
# Epoch 131/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8538 - loss: 0.3699 - val_accuracy: 0.7582 - val_loss: 1.1035
# Epoch 132/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8264 - loss: 0.3983 - val_accuracy: 0.7418 - val_loss: 1.0364
# Epoch 133/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8639 - loss: 0.3583 - val_accuracy: 0.7732 - val_loss: 0.9883
# Epoch 134/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8540 - loss: 0.3880 - val_accuracy: 0.7637 - val_loss: 1.1463
# Epoch 135/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8729 - loss: 0.3309 - val_accuracy: 0.7637 - val_loss: 1.0459
# Epoch 136/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8522 - loss: 0.3881 - val_accuracy: 0.7596 - val_loss: 1.0783
# Epoch 137/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8481 - loss: 0.3755 - val_accuracy: 0.7486 - val_loss: 1.0610
# Epoch 138/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8555 - loss: 0.3704 - val_accuracy: 0.7432 - val_loss: 1.0370
# Epoch 139/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8630 - loss: 0.3557 - val_accuracy: 0.7596 - val_loss: 1.0522
# Epoch 140/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8567 - loss: 0.3775 - val_accuracy: 0.7568 - val_loss: 1.0781
# Epoch 141/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8669 - loss: 0.3499 - val_accuracy: 0.7596 - val_loss: 0.9996
# Epoch 142/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8561 - loss: 0.3974 - val_accuracy: 0.7514 - val_loss: 1.0986
# Epoch 143/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8620 - loss: 0.3496 - val_accuracy: 0.7623 - val_loss: 0.9874
# Epoch 144/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8603 - loss: 0.3528 - val_accuracy: 0.7678 - val_loss: 0.9868
# Epoch 145/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8493 - loss: 0.3584 - val_accuracy: 0.7664 - val_loss: 1.0419
# Epoch 146/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8481 - loss: 0.3853 - val_accuracy: 0.7828 - val_loss: 0.9602
# Epoch 147/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8622 - loss: 0.3667 - val_accuracy: 0.7664 - val_loss: 1.0487
# Epoch 148/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8571 - loss: 0.3688 - val_accuracy: 0.7541 - val_loss: 1.0429
# Epoch 149/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8634 - loss: 0.3407 - val_accuracy: 0.7623 - val_loss: 0.9541
# Epoch 150/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8594 - loss: 0.3593 - val_accuracy: 0.7623 - val_loss: 0.9926
# Epoch 151/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8519 - loss: 0.3685 - val_accuracy: 0.7445 - val_loss: 0.9321
# Epoch 152/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8567 - loss: 0.3749 - val_accuracy: 0.7404 - val_loss: 1.1295
# Epoch 153/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8625 - loss: 0.3647 - val_accuracy: 0.7664 - val_loss: 0.9360
# Epoch 154/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8503 - loss: 0.3956 - val_accuracy: 0.7473 - val_loss: 0.9824
# Epoch 155/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8578 - loss: 0.3819 - val_accuracy: 0.7459 - val_loss: 1.0610
# Epoch 156/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8470 - loss: 0.3849 - val_accuracy: 0.7541 - val_loss: 0.9832
# Epoch 157/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8692 - loss: 0.3631 - val_accuracy: 0.7541 - val_loss: 0.9141
# Epoch 158/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8649 - loss: 0.3703 - val_accuracy: 0.7527 - val_loss: 0.8905
# Epoch 159/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8467 - loss: 0.3762 - val_accuracy: 0.7555 - val_loss: 0.9953
# Epoch 160/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8695 - loss: 0.3456 - val_accuracy: 0.7432 - val_loss: 0.9603
# Epoch 161/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8628 - loss: 0.3697 - val_accuracy: 0.7596 - val_loss: 1.1243
# Epoch 162/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8341 - loss: 0.4452 - val_accuracy: 0.7432 - val_loss: 1.0418
# Epoch 163/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8708 - loss: 0.3419 - val_accuracy: 0.7555 - val_loss: 1.1526
# Epoch 164/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8556 - loss: 0.3722 - val_accuracy: 0.7527 - val_loss: 1.0285
# Epoch 165/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8463 - loss: 0.3631 - val_accuracy: 0.7637 - val_loss: 1.0989
# Epoch 166/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8673 - loss: 0.3500 - val_accuracy: 0.7650 - val_loss: 1.2751
# Epoch 167/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8605 - loss: 0.3824 - val_accuracy: 0.7445 - val_loss: 0.9508
# Epoch 168/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8595 - loss: 0.3714 - val_accuracy: 0.7582 - val_loss: 0.9375
# Epoch 169/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8703 - loss: 0.3623 - val_accuracy: 0.7555 - val_loss: 0.9665
# Epoch 170/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8522 - loss: 0.3770 - val_accuracy: 0.7486 - val_loss: 1.0920
# Epoch 171/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8717 - loss: 0.3338 - val_accuracy: 0.7418 - val_loss: 0.9937
# Epoch 172/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8447 - loss: 0.3881 - val_accuracy: 0.7568 - val_loss: 1.1258
# Epoch 173/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8589 - loss: 0.3666 - val_accuracy: 0.7322 - val_loss: 1.2380
# Epoch 174/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8637 - loss: 0.3517 - val_accuracy: 0.7637 - val_loss: 1.0016
# Epoch 175/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8537 - loss: 0.3613 - val_accuracy: 0.7555 - val_loss: 0.9865
# Epoch 176/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8623 - loss: 0.3713 - val_accuracy: 0.7568 - val_loss: 1.0467
# Epoch 177/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8690 - loss: 0.3365 - val_accuracy: 0.7609 - val_loss: 0.9610
# Epoch 178/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8535 - loss: 0.3823 - val_accuracy: 0.7582 - val_loss: 0.9876
# Epoch 179/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8470 - loss: 0.3808 - val_accuracy: 0.7582 - val_loss: 1.0471
# Epoch 180/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8594 - loss: 0.3780 - val_accuracy: 0.7637 - val_loss: 0.9468
# Epoch 181/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8505 - loss: 0.4003 - val_accuracy: 0.7527 - val_loss: 1.0051
# Epoch 182/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8619 - loss: 0.3484 - val_accuracy: 0.7596 - val_loss: 1.0066
# Epoch 183/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8594 - loss: 0.3593 - val_accuracy: 0.7377 - val_loss: 1.1105
# Epoch 184/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8465 - loss: 0.3857 - val_accuracy: 0.7500 - val_loss: 1.0283
# Epoch 185/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8542 - loss: 0.3735 - val_accuracy: 0.7568 - val_loss: 1.0227
# Epoch 186/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8664 - loss: 0.3602 - val_accuracy: 0.7514 - val_loss: 1.0574
# Epoch 187/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8559 - loss: 0.3731 - val_accuracy: 0.7404 - val_loss: 1.1598
# Epoch 188/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8635 - loss: 0.3367 - val_accuracy: 0.7391 - val_loss: 1.0679
# Epoch 189/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8548 - loss: 0.3726 - val_accuracy: 0.7295 - val_loss: 1.0688
# Epoch 190/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8556 - loss: 0.3834 - val_accuracy: 0.7568 - val_loss: 0.9748
# Epoch 191/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8543 - loss: 0.3654 - val_accuracy: 0.7500 - val_loss: 1.0064
# Epoch 192/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8599 - loss: 0.3625 - val_accuracy: 0.7445 - val_loss: 1.1120
# Epoch 193/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8532 - loss: 0.3693 - val_accuracy: 0.7582 - val_loss: 1.1163
# Epoch 194/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8622 - loss: 0.3586 - val_accuracy: 0.7678 - val_loss: 1.0004
# Epoch 195/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8721 - loss: 0.3422 - val_accuracy: 0.7596 - val_loss: 0.9592
# Epoch 196/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8441 - loss: 0.3856 - val_accuracy: 0.7596 - val_loss: 1.1415
# Epoch 197/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8390 - loss: 0.4109 - val_accuracy: 0.7363 - val_loss: 1.0965
# Epoch 198/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8661 - loss: 0.3517 - val_accuracy: 0.7609 - val_loss: 1.0230
# Epoch 199/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8558 - loss: 0.3630 - val_accuracy: 0.7555 - val_loss: 1.0133
# Epoch 200/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8637 - loss: 0.3404 - val_accuracy: 0.7678 - val_loss: 1.0694
# Epoch 201/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8686 - loss: 0.3485 - val_accuracy: 0.7459 - val_loss: 1.0470
# Epoch 202/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8534 - loss: 0.3817 - val_accuracy: 0.7391 - val_loss: 1.1120
# Epoch 203/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8418 - loss: 0.4110 - val_accuracy: 0.7404 - val_loss: 0.9997
# Epoch 204/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8663 - loss: 0.3473 - val_accuracy: 0.7582 - val_loss: 0.9748
# Epoch 205/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8616 - loss: 0.3571 - val_accuracy: 0.7596 - val_loss: 0.9549
# Epoch 206/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8634 - loss: 0.3521 - val_accuracy: 0.7445 - val_loss: 0.9503
# Epoch 207/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8494 - loss: 0.3842 - val_accuracy: 0.7650 - val_loss: 0.9877
# Epoch 208/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8590 - loss: 0.3512 - val_accuracy: 0.7568 - val_loss: 1.0875
# Epoch 209/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8503 - loss: 0.3898 - val_accuracy: 0.7473 - val_loss: 1.0268
# Epoch 210/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8534 - loss: 0.3619 - val_accuracy: 0.7527 - val_loss: 1.0104
# Epoch 211/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8789 - loss: 0.3372 - val_accuracy: 0.7527 - val_loss: 0.9714
# Epoch 212/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8540 - loss: 0.3549 - val_accuracy: 0.7664 - val_loss: 0.9477
# Epoch 213/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8691 - loss: 0.3560 - val_accuracy: 0.7473 - val_loss: 1.1668
# Epoch 214/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8532 - loss: 0.3926 - val_accuracy: 0.7568 - val_loss: 0.9564
# Epoch 215/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8731 - loss: 0.3514 - val_accuracy: 0.7527 - val_loss: 0.9038
# Epoch 216/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8603 - loss: 0.3792 - val_accuracy: 0.7705 - val_loss: 0.9283
# Epoch 217/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8488 - loss: 0.3794 - val_accuracy: 0.7527 - val_loss: 1.0957
# Epoch 218/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8708 - loss: 0.3322 - val_accuracy: 0.7801 - val_loss: 0.9349
# Epoch 219/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8701 - loss: 0.3396 - val_accuracy: 0.7445 - val_loss: 1.0657
# Epoch 220/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8648 - loss: 0.3481 - val_accuracy: 0.7678 - val_loss: 1.0387
# Epoch 221/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8713 - loss: 0.3519 - val_accuracy: 0.7514 - val_loss: 0.9653
# Epoch 222/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8824 - loss: 0.3362 - val_accuracy: 0.7350 - val_loss: 1.0331
# Epoch 223/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8689 - loss: 0.3371 - val_accuracy: 0.7568 - val_loss: 0.9647
# Epoch 224/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8640 - loss: 0.3573 - val_accuracy: 0.7377 - val_loss: 1.0215
# Epoch 225/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8595 - loss: 0.3519 - val_accuracy: 0.7650 - val_loss: 1.0147
# Epoch 226/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8550 - loss: 0.3677 - val_accuracy: 0.7459 - val_loss: 0.9962
# Epoch 227/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8597 - loss: 0.3547 - val_accuracy: 0.7637 - val_loss: 0.9358
# Epoch 228/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8720 - loss: 0.3255 - val_accuracy: 0.7650 - val_loss: 1.0315
# Epoch 229/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8616 - loss: 0.3727 - val_accuracy: 0.7609 - val_loss: 0.9929
# Epoch 230/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8484 - loss: 0.3989 - val_accuracy: 0.7746 - val_loss: 1.0119
# Epoch 231/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8591 - loss: 0.3507 - val_accuracy: 0.7650 - val_loss: 0.9533
# Epoch 232/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8426 - loss: 0.3927 - val_accuracy: 0.7746 - val_loss: 0.9418
# Epoch 233/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8641 - loss: 0.3529 - val_accuracy: 0.7568 - val_loss: 1.0234
# Epoch 234/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8562 - loss: 0.3539 - val_accuracy: 0.7336 - val_loss: 1.0776
# Epoch 235/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8555 - loss: 0.3662 - val_accuracy: 0.7568 - val_loss: 1.0126
# Epoch 236/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8700 - loss: 0.3397 - val_accuracy: 0.7787 - val_loss: 0.9661
# Epoch 237/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8646 - loss: 0.3607 - val_accuracy: 0.7527 - val_loss: 1.0583
# Epoch 238/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8838 - loss: 0.3181 - val_accuracy: 0.7678 - val_loss: 0.9279
# Epoch 239/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8559 - loss: 0.3735 - val_accuracy: 0.7527 - val_loss: 1.1007
# Epoch 240/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8460 - loss: 0.3871 - val_accuracy: 0.7637 - val_loss: 1.0384
# Epoch 241/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8668 - loss: 0.3545 - val_accuracy: 0.7541 - val_loss: 1.0565
# Epoch 242/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8692 - loss: 0.3516 - val_accuracy: 0.7650 - val_loss: 1.0585
# Epoch 243/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8722 - loss: 0.3444 - val_accuracy: 0.7541 - val_loss: 1.0879
# Epoch 244/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8618 - loss: 0.3654 - val_accuracy: 0.7555 - val_loss: 1.0011
# Epoch 245/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8632 - loss: 0.3572 - val_accuracy: 0.7705 - val_loss: 0.9826
# Epoch 246/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8659 - loss: 0.3465 - val_accuracy: 0.7609 - val_loss: 1.0057
# Epoch 247/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8570 - loss: 0.3572 - val_accuracy: 0.7664 - val_loss: 1.1001
# Epoch 248/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8681 - loss: 0.3383 - val_accuracy: 0.7691 - val_loss: 1.1032
# Epoch 249/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8466 - loss: 0.3973 - val_accuracy: 0.7254 - val_loss: 1.0917
# Epoch 250/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8450 - loss: 0.3911 - val_accuracy: 0.7514 - val_loss: 1.0415
# Epoch 251/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8750 - loss: 0.3181 - val_accuracy: 0.7363 - val_loss: 1.1399
# Epoch 252/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8638 - loss: 0.3435 - val_accuracy: 0.7568 - val_loss: 0.9908
# Epoch 253/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8579 - loss: 0.3741 - val_accuracy: 0.7664 - val_loss: 0.8992
# Epoch 254/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8658 - loss: 0.3380 - val_accuracy: 0.7596 - val_loss: 1.1190
# Epoch 255/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8624 - loss: 0.3658 - val_accuracy: 0.7500 - val_loss: 1.0232
# Epoch 256/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8674 - loss: 0.3654 - val_accuracy: 0.7404 - val_loss: 1.0066
# Epoch 257/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8629 - loss: 0.3392 - val_accuracy: 0.7541 - val_loss: 1.0149
# Epoch 258/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8564 - loss: 0.3701 - val_accuracy: 0.7527 - val_loss: 0.9796
# Epoch 259/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8782 - loss: 0.3134 - val_accuracy: 0.7500 - val_loss: 0.9316
# Epoch 260/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8763 - loss: 0.3358 - val_accuracy: 0.7582 - val_loss: 0.9906
# Epoch 261/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8801 - loss: 0.3333 - val_accuracy: 0.7555 - val_loss: 1.0192
# Epoch 262/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8573 - loss: 0.3415 - val_accuracy: 0.7486 - val_loss: 1.2055
# Epoch 263/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8697 - loss: 0.3772 - val_accuracy: 0.7377 - val_loss: 1.1195
# Epoch 264/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8733 - loss: 0.3205 - val_accuracy: 0.7486 - val_loss: 1.0090
# Epoch 265/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8786 - loss: 0.3149 - val_accuracy: 0.7363 - val_loss: 1.0934
# Epoch 266/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8735 - loss: 0.3228 - val_accuracy: 0.7527 - val_loss: 1.0128
# Epoch 267/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8755 - loss: 0.3370 - val_accuracy: 0.7664 - val_loss: 1.0123
# Epoch 268/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8585 - loss: 0.3667 - val_accuracy: 0.7623 - val_loss: 1.0399
# Epoch 269/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8807 - loss: 0.3138 - val_accuracy: 0.7527 - val_loss: 1.0589
# Epoch 270/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8626 - loss: 0.3528 - val_accuracy: 0.7582 - val_loss: 1.1187
# Epoch 271/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8575 - loss: 0.3624 - val_accuracy: 0.7596 - val_loss: 0.9733
# Epoch 272/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8693 - loss: 0.3478 - val_accuracy: 0.7432 - val_loss: 1.0235
# Epoch 273/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8637 - loss: 0.3336 - val_accuracy: 0.7459 - val_loss: 1.2048
# Epoch 274/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8578 - loss: 0.3516 - val_accuracy: 0.7609 - val_loss: 1.1649
# Epoch 275/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8682 - loss: 0.3466 - val_accuracy: 0.7459 - val_loss: 1.1705
# Epoch 276/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8578 - loss: 0.3872 - val_accuracy: 0.7514 - val_loss: 0.9948
# Epoch 277/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8646 - loss: 0.3401 - val_accuracy: 0.7568 - val_loss: 1.0517
# Epoch 278/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8656 - loss: 0.3512 - val_accuracy: 0.7527 - val_loss: 0.9979
# Epoch 279/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8689 - loss: 0.3406 - val_accuracy: 0.7582 - val_loss: 1.0742
# Epoch 280/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8638 - loss: 0.3347 - val_accuracy: 0.7609 - val_loss: 1.0334
# Epoch 281/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8620 - loss: 0.3686 - val_accuracy: 0.7746 - val_loss: 1.0492
# Epoch 282/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8755 - loss: 0.3198 - val_accuracy: 0.7459 - val_loss: 1.1304
# Epoch 283/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8717 - loss: 0.3485 - val_accuracy: 0.7568 - val_loss: 1.0885
# Epoch 284/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8695 - loss: 0.3549 - val_accuracy: 0.7609 - val_loss: 0.9165
# Epoch 285/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8728 - loss: 0.3209 - val_accuracy: 0.7637 - val_loss: 1.1312
# Epoch 286/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8627 - loss: 0.3442 - val_accuracy: 0.7637 - val_loss: 0.9960
# Epoch 287/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8593 - loss: 0.3651 - val_accuracy: 0.7555 - val_loss: 1.1485
# Epoch 288/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.8756 - loss: 0.3445 - val_accuracy: 0.7445 - val_loss: 1.0747
# Epoch 289/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8616 - loss: 0.3596 - val_accuracy: 0.7199 - val_loss: 1.2631
# Epoch 290/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8414 - loss: 0.3864 - val_accuracy: 0.7473 - val_loss: 1.1717
# Epoch 291/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8727 - loss: 0.3523 - val_accuracy: 0.7637 - val_loss: 0.9867
# Epoch 292/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8455 - loss: 0.3865 - val_accuracy: 0.7350 - val_loss: 0.9997
# Epoch 293/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8682 - loss: 0.3299 - val_accuracy: 0.7596 - val_loss: 1.0020
# Epoch 294/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8647 - loss: 0.3364 - val_accuracy: 0.7432 - val_loss: 1.0577
# Epoch 295/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8611 - loss: 0.3359 - val_accuracy: 0.7459 - val_loss: 1.0822
# Epoch 296/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8605 - loss: 0.3338 - val_accuracy: 0.7527 - val_loss: 1.0709
# Epoch 297/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8588 - loss: 0.3559 - val_accuracy: 0.7445 - val_loss: 1.0527
# Epoch 298/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8696 - loss: 0.3330 - val_accuracy: 0.7459 - val_loss: 1.0475
# Epoch 299/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8599 - loss: 0.3539 - val_accuracy: 0.7705 - val_loss: 1.0506
# Epoch 300/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8655 - loss: 0.3618 - val_accuracy: 0.7527 - val_loss: 1.1561
# Epoch 301/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8620 - loss: 0.3536 - val_accuracy: 0.7541 - val_loss: 1.1010
# Epoch 302/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8642 - loss: 0.3560 - val_accuracy: 0.7445 - val_loss: 1.2793
# Epoch 303/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8790 - loss: 0.3223 - val_accuracy: 0.7623 - val_loss: 1.0644
# Epoch 304/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8686 - loss: 0.3547 - val_accuracy: 0.7637 - val_loss: 1.0431
# Epoch 305/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8503 - loss: 0.3605 - val_accuracy: 0.7664 - val_loss: 1.0513
# Epoch 306/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8743 - loss: 0.3163 - val_accuracy: 0.7459 - val_loss: 1.1103
# Epoch 307/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8756 - loss: 0.3171 - val_accuracy: 0.7404 - val_loss: 1.0490
# Epoch 308/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8787 - loss: 0.3305 - val_accuracy: 0.7555 - val_loss: 1.0795
# Epoch 309/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8722 - loss: 0.3259 - val_accuracy: 0.7473 - val_loss: 1.0435
# Epoch 310/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8733 - loss: 0.3293 - val_accuracy: 0.7609 - val_loss: 1.0946
# Epoch 311/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8620 - loss: 0.3474 - val_accuracy: 0.7541 - val_loss: 1.0463
# Epoch 312/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8794 - loss: 0.3257 - val_accuracy: 0.7404 - val_loss: 1.2202
# Epoch 313/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8602 - loss: 0.3786 - val_accuracy: 0.7473 - val_loss: 1.0460
# Epoch 314/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8694 - loss: 0.3391 - val_accuracy: 0.7678 - val_loss: 1.0401
# Epoch 315/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8769 - loss: 0.3228 - val_accuracy: 0.7445 - val_loss: 1.0543
# Epoch 316/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8526 - loss: 0.3704 - val_accuracy: 0.7609 - val_loss: 1.0109
# Epoch 317/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8718 - loss: 0.3328 - val_accuracy: 0.7350 - val_loss: 1.0444
# Epoch 318/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8793 - loss: 0.3283 - val_accuracy: 0.7514 - val_loss: 1.0500
# Epoch 319/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8714 - loss: 0.3195 - val_accuracy: 0.7186 - val_loss: 1.1844
# Epoch 320/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8819 - loss: 0.3266 - val_accuracy: 0.7527 - val_loss: 0.9907
# Epoch 321/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8593 - loss: 0.3407 - val_accuracy: 0.7445 - val_loss: 1.0211
# Epoch 322/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8699 - loss: 0.3275 - val_accuracy: 0.7268 - val_loss: 0.9811
# Epoch 323/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8656 - loss: 0.3542 - val_accuracy: 0.7582 - val_loss: 1.0590
# Epoch 324/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8846 - loss: 0.3347 - val_accuracy: 0.7568 - val_loss: 1.1255
# Epoch 325/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8778 - loss: 0.3378 - val_accuracy: 0.7623 - val_loss: 1.0031
# Epoch 326/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8566 - loss: 0.3552 - val_accuracy: 0.7404 - val_loss: 1.0894
# Epoch 327/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8768 - loss: 0.3216 - val_accuracy: 0.7623 - val_loss: 1.0105
# Epoch 328/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8690 - loss: 0.3637 - val_accuracy: 0.7527 - val_loss: 1.1631
# Epoch 329/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8701 - loss: 0.3309 - val_accuracy: 0.7637 - val_loss: 1.1493
# Epoch 330/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8730 - loss: 0.3427 - val_accuracy: 0.7391 - val_loss: 1.1351
# Epoch 331/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8644 - loss: 0.3434 - val_accuracy: 0.7418 - val_loss: 1.1828
# Epoch 332/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8703 - loss: 0.3401 - val_accuracy: 0.7555 - val_loss: 1.1595
# Epoch 333/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8607 - loss: 0.3403 - val_accuracy: 0.7596 - val_loss: 1.0476
# Epoch 334/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8672 - loss: 0.3349 - val_accuracy: 0.7445 - val_loss: 1.1172
# Epoch 335/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8649 - loss: 0.3267 - val_accuracy: 0.7432 - val_loss: 1.0766
# Epoch 336/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8711 - loss: 0.3209 - val_accuracy: 0.7445 - val_loss: 1.2170
# Epoch 337/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8737 - loss: 0.3245 - val_accuracy: 0.7582 - val_loss: 1.0929
# Epoch 338/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8637 - loss: 0.3483 - val_accuracy: 0.7445 - val_loss: 1.1078
# Epoch 339/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8671 - loss: 0.3330 - val_accuracy: 0.7514 - val_loss: 1.0798
# Epoch 340/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8760 - loss: 0.3362 - val_accuracy: 0.7541 - val_loss: 1.0660
# Epoch 341/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8682 - loss: 0.3621 - val_accuracy: 0.7336 - val_loss: 1.1047
# Epoch 342/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8715 - loss: 0.3360 - val_accuracy: 0.7637 - val_loss: 1.0511
# Epoch 343/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8799 - loss: 0.3144 - val_accuracy: 0.7691 - val_loss: 1.1253
# Epoch 344/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8604 - loss: 0.3745 - val_accuracy: 0.7527 - val_loss: 1.1423
# Epoch 345/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.8654 - loss: 0.3521 - val_accuracy: 0.7732 - val_loss: 1.0441
# Epoch 346/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8691 - loss: 0.3449 - val_accuracy: 0.7418 - val_loss: 1.1456
# Epoch 347/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8629 - loss: 0.3652 - val_accuracy: 0.7514 - val_loss: 1.1565
# Epoch 348/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8674 - loss: 0.3459 - val_accuracy: 0.7650 - val_loss: 0.9493
# Epoch 349/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8599 - loss: 0.3755 - val_accuracy: 0.7582 - val_loss: 1.1107
# Epoch 350/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8696 - loss: 0.3228 - val_accuracy: 0.7500 - val_loss: 1.0918
# Epoch 351/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8691 - loss: 0.3353 - val_accuracy: 0.7404 - val_loss: 1.1574
# Epoch 352/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8668 - loss: 0.3345 - val_accuracy: 0.7445 - val_loss: 1.0352
# Epoch 353/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8718 - loss: 0.3639 - val_accuracy: 0.7350 - val_loss: 1.0842
# Epoch 354/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8639 - loss: 0.3742 - val_accuracy: 0.7609 - val_loss: 0.9542
# Epoch 355/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8614 - loss: 0.3657 - val_accuracy: 0.7473 - val_loss: 1.0106
# Epoch 356/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8760 - loss: 0.3357 - val_accuracy: 0.7787 - val_loss: 1.0689
# Epoch 357/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8644 - loss: 0.3413 - val_accuracy: 0.7500 - val_loss: 1.0549
# Epoch 358/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8788 - loss: 0.3071 - val_accuracy: 0.7568 - val_loss: 1.0825
# Epoch 359/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8677 - loss: 0.3435 - val_accuracy: 0.7582 - val_loss: 1.0607
# Epoch 360/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8739 - loss: 0.3173 - val_accuracy: 0.7486 - val_loss: 1.0562
# Epoch 361/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8773 - loss: 0.3296 - val_accuracy: 0.7555 - val_loss: 1.1473
# Epoch 362/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8778 - loss: 0.3217 - val_accuracy: 0.7418 - val_loss: 1.0951
# Epoch 363/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8711 - loss: 0.3187 - val_accuracy: 0.7555 - val_loss: 1.0617
# Epoch 364/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8826 - loss: 0.3280 - val_accuracy: 0.7623 - val_loss: 1.1880
# Epoch 365/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8735 - loss: 0.3363 - val_accuracy: 0.7418 - val_loss: 1.1017
# Epoch 366/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8699 - loss: 0.3411 - val_accuracy: 0.7555 - val_loss: 1.1078
# Epoch 367/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8629 - loss: 0.3580 - val_accuracy: 0.7295 - val_loss: 1.0835
# Epoch 368/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8726 - loss: 0.3203 - val_accuracy: 0.7377 - val_loss: 1.3529
# Epoch 369/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8756 - loss: 0.3388 - val_accuracy: 0.7418 - val_loss: 1.1071
# Epoch 370/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8688 - loss: 0.3470 - val_accuracy: 0.7473 - val_loss: 1.0395
# ...
# Epoch 378/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8720 - loss: 0.3203 - val_accuracy: 0.7445 - val_loss: 1.0233
# Epoch 379/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8705 - loss: 0.3387 - val_accuracy: 0.7637 - val_loss: 1.0763
# Epoch 380/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8608 - loss: 0.3629 - val_accuracy: 0.7637 - val_loss: 1.0696
# Epoch 381/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8767 - loss: 0.3250 - val_accuracy: 0.7500 - val_loss: 1.1111
# Epoch 382/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8682 - loss: 0.3364 - val_accuracy: 0.7623 - val_loss: 1.0470
# Epoch 383/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8766 - loss: 0.3318 - val_accuracy: 0.7445 - val_loss: 0.9863
# Epoch 384/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8880 - loss: 0.3021 - val_accuracy: 0.7678 - val_loss: 1.1427
# Epoch 385/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8688 - loss: 0.3396 - val_accuracy: 0.7555 - val_loss: 1.1136
# Epoch 386/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8605 - loss: 0.3574 - val_accuracy: 0.7650 - val_loss: 1.0843
# Epoch 387/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8775 - loss: 0.3216 - val_accuracy: 0.7445 - val_loss: 1.1115
# Epoch 388/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8676 - loss: 0.3454 - val_accuracy: 0.7500 - val_loss: 1.1586
# Epoch 389/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8795 - loss: 0.3151 - val_accuracy: 0.7596 - val_loss: 1.2214
# Epoch 390/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8701 - loss: 0.3355 - val_accuracy: 0.7691 - val_loss: 1.0436
# Epoch 391/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8804 - loss: 0.3096 - val_accuracy: 0.7719 - val_loss: 0.9608
# Epoch 392/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.8743 - loss: 0.3377 - val_accuracy: 0.7486 - val_loss: 1.0522
# Epoch 393/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8594 - loss: 0.3427 - val_accuracy: 0.7541 - val_loss: 1.0924
# Epoch 394/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8767 - loss: 0.3219 - val_accuracy: 0.7582 - val_loss: 1.0205
# Epoch 395/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8617 - loss: 0.3442 - val_accuracy: 0.7541 - val_loss: 1.0332
# Epoch 396/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8921 - loss: 0.3005 - val_accuracy: 0.7568 - val_loss: 1.3098
# Epoch 397/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8746 - loss: 0.3507 - val_accuracy: 0.7527 - val_loss: 1.2038
# Epoch 398/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8819 - loss: 0.3173 - val_accuracy: 0.7650 - val_loss: 1.1639
# Epoch 399/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8652 - loss: 0.3544 - val_accuracy: 0.7705 - val_loss: 1.0258
# Epoch 400/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8616 - loss: 0.3374 - val_accuracy: 0.7650 - val_loss: 1.0665
# Epoch 401/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8878 - loss: 0.3307 - val_accuracy: 0.7609 - val_loss: 1.0782
# Epoch 402/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8737 - loss: 0.3395 - val_accuracy: 0.7609 - val_loss: 0.9782
# Epoch 403/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8692 - loss: 0.3337 - val_accuracy: 0.7541 - val_loss: 1.1823
# Epoch 404/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8777 - loss: 0.3430 - val_accuracy: 0.7391 - val_loss: 1.1614
# Epoch 405/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - accuracy: 0.8783 - loss: 0.3218 - val_accuracy: 0.7227 - val_loss: 1.1595
# Epoch 406/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8689 - loss: 0.3446 - val_accuracy: 0.7555 - val_loss: 1.0347
# Epoch 407/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8716 - loss: 0.3322 - val_accuracy: 0.7623 - val_loss: 1.0567
# Epoch 408/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.8594 - loss: 0.3548 - val_accuracy: 0.7418 - val_loss: 1.1594
# Epoch 409/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8666 - loss: 0.3412 - val_accuracy: 0.7445 - val_loss: 1.0474
# Epoch 410/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8856 - loss: 0.3002 - val_accuracy: 0.7377 - val_loss: 1.1096
# Epoch 411/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8627 - loss: 0.3452 - val_accuracy: 0.7459 - val_loss: 1.3206
# Epoch 412/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8786 - loss: 0.3144 - val_accuracy: 0.7650 - val_loss: 1.1583
# Epoch 413/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8741 - loss: 0.3225 - val_accuracy: 0.7650 - val_loss: 1.1749
# Epoch 414/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8812 - loss: 0.3430 - val_accuracy: 0.7691 - val_loss: 1.1016
# Epoch 415/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8663 - loss: 0.3470 - val_accuracy: 0.7541 - val_loss: 1.1141
# Epoch 416/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8747 - loss: 0.3208 - val_accuracy: 0.7391 - val_loss: 1.2871
# Epoch 417/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8848 - loss: 0.3090 - val_accuracy: 0.7445 - val_loss: 1.0173
# Epoch 418/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8812 - loss: 0.3000 - val_accuracy: 0.7445 - val_loss: 1.2762
# Epoch 419/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8805 - loss: 0.3226 - val_accuracy: 0.7418 - val_loss: 1.2259
# Epoch 420/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8706 - loss: 0.3259 - val_accuracy: 0.7541 - val_loss: 1.0107
# Epoch 421/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8696 - loss: 0.3236 - val_accuracy: 0.7295 - val_loss: 1.2407
# Epoch 422/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8741 - loss: 0.3361 - val_accuracy: 0.7555 - val_loss: 1.0744
# Epoch 423/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8990 - loss: 0.2621 - val_accuracy: 0.7473 - val_loss: 1.0664
# Epoch 424/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8708 - loss: 0.3259 - val_accuracy: 0.7582 - val_loss: 1.0462
# Epoch 425/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8849 - loss: 0.3104 - val_accuracy: 0.7404 - val_loss: 1.1966
# Epoch 426/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8711 - loss: 0.3514 - val_accuracy: 0.7582 - val_loss: 1.1114
# Epoch 427/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8701 - loss: 0.3208 - val_accuracy: 0.7486 - val_loss: 1.2757
# Epoch 428/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8807 - loss: 0.3199 - val_accuracy: 0.7746 - val_loss: 1.1286
# Epoch 429/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8751 - loss: 0.3139 - val_accuracy: 0.7432 - val_loss: 1.1408
# Epoch 430/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8673 - loss: 0.3411 - val_accuracy: 0.7363 - val_loss: 1.1872
# Epoch 431/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8734 - loss: 0.3213 - val_accuracy: 0.7596 - val_loss: 1.0488
# Epoch 432/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8727 - loss: 0.3297 - val_accuracy: 0.7568 - val_loss: 1.0591
# Epoch 433/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8761 - loss: 0.3310 - val_accuracy: 0.7664 - val_loss: 1.0651
# Epoch 434/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8721 - loss: 0.3194 - val_accuracy: 0.7609 - val_loss: 1.2372
# Epoch 435/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8860 - loss: 0.3065 - val_accuracy: 0.7541 - val_loss: 1.1422
# Epoch 436/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8859 - loss: 0.3076 - val_accuracy: 0.7568 - val_loss: 1.0874
# Epoch 437/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8757 - loss: 0.3144 - val_accuracy: 0.7637 - val_loss: 1.1409
# Epoch 438/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8700 - loss: 0.3350 - val_accuracy: 0.7678 - val_loss: 1.0464
# Epoch 439/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8722 - loss: 0.3341 - val_accuracy: 0.7801 - val_loss: 1.1052
# Epoch 440/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8675 - loss: 0.2993 - val_accuracy: 0.7486 - val_loss: 1.1960
# Epoch 441/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8826 - loss: 0.3193 - val_accuracy: 0.7678 - val_loss: 1.1480
# Epoch 442/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 31ms/step - accuracy: 0.8699 - loss: 0.3295 - val_accuracy: 0.7664 - val_loss: 1.1064
# Epoch 443/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8767 - loss: 0.3256 - val_accuracy: 0.7637 - val_loss: 1.1620
# Epoch 444/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8785 - loss: 0.3217 - val_accuracy: 0.7527 - val_loss: 1.1149
# Epoch 445/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8688 - loss: 0.3305 - val_accuracy: 0.7473 - val_loss: 1.0168
# Epoch 446/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8730 - loss: 0.3315 - val_accuracy: 0.7500 - val_loss: 1.1641
# Epoch 447/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8724 - loss: 0.3216 - val_accuracy: 0.7295 - val_loss: 1.2637
# Epoch 448/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8817 - loss: 0.3194 - val_accuracy: 0.7650 - val_loss: 1.0997
# Epoch 449/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8636 - loss: 0.3306 - val_accuracy: 0.7459 - val_loss: 1.1538
# Epoch 450/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8817 - loss: 0.3038 - val_accuracy: 0.7691 - val_loss: 1.0353
# Epoch 451/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8812 - loss: 0.2983 - val_accuracy: 0.7609 - val_loss: 1.1165
# Epoch 452/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8822 - loss: 0.3152 - val_accuracy: 0.7719 - val_loss: 1.1730
# Epoch 453/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8603 - loss: 0.3343 - val_accuracy: 0.7527 - val_loss: 1.0910
# Epoch 454/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8774 - loss: 0.3111 - val_accuracy: 0.7541 - val_loss: 1.1517
# Epoch 455/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8777 - loss: 0.3201 - val_accuracy: 0.7473 - val_loss: 1.0666
# Epoch 456/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8743 - loss: 0.3391 - val_accuracy: 0.7664 - val_loss: 1.1572
# Epoch 457/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8860 - loss: 0.3059 - val_accuracy: 0.7432 - val_loss: 1.2461
# Epoch 458/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8789 - loss: 0.3172 - val_accuracy: 0.7609 - val_loss: 1.2452
# Epoch 459/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8691 - loss: 0.3546 - val_accuracy: 0.7596 - val_loss: 1.1409
# Epoch 460/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8819 - loss: 0.3092 - val_accuracy: 0.7500 - val_loss: 1.1855
# Epoch 461/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8738 - loss: 0.3463 - val_accuracy: 0.7500 - val_loss: 1.1186
# Epoch 462/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8798 - loss: 0.3148 - val_accuracy: 0.7486 - val_loss: 1.0401
# Epoch 463/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8808 - loss: 0.3128 - val_accuracy: 0.7623 - val_loss: 1.0523
# Epoch 464/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8712 - loss: 0.3195 - val_accuracy: 0.7568 - val_loss: 1.0747
# Epoch 465/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8923 - loss: 0.2891 - val_accuracy: 0.7500 - val_loss: 1.1258
# Epoch 466/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8706 - loss: 0.3061 - val_accuracy: 0.7500 - val_loss: 1.0791
# Epoch 467/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8913 - loss: 0.2977 - val_accuracy: 0.7404 - val_loss: 1.2025
# Epoch 468/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8710 - loss: 0.3338 - val_accuracy: 0.7445 - val_loss: 1.1870
# Epoch 469/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8887 - loss: 0.3147 - val_accuracy: 0.7541 - val_loss: 1.2526
# Epoch 470/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8742 - loss: 0.3211 - val_accuracy: 0.7637 - val_loss: 1.1255
# Epoch 471/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8725 - loss: 0.3452 - val_accuracy: 0.7732 - val_loss: 1.0024
# Epoch 472/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8853 - loss: 0.3102 - val_accuracy: 0.7568 - val_loss: 1.0981
# Epoch 473/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8818 - loss: 0.3012 - val_accuracy: 0.7732 - val_loss: 1.1178
# Epoch 474/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8716 - loss: 0.3362 - val_accuracy: 0.7664 - val_loss: 1.0623
# Epoch 475/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8655 - loss: 0.3369 - val_accuracy: 0.7527 - val_loss: 1.1486
# Epoch 476/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8890 - loss: 0.2929 - val_accuracy: 0.7678 - val_loss: 1.0699
# Epoch 477/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8689 - loss: 0.3478 - val_accuracy: 0.7391 - val_loss: 1.0815
# Epoch 478/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8742 - loss: 0.3432 - val_accuracy: 0.7555 - val_loss: 1.1539
# Epoch 479/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8873 - loss: 0.3066 - val_accuracy: 0.7637 - val_loss: 1.0869
# Epoch 480/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8891 - loss: 0.2782 - val_accuracy: 0.7582 - val_loss: 1.0744
# Epoch 481/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8751 - loss: 0.3342 - val_accuracy: 0.7896 - val_loss: 1.0608
# Epoch 482/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.8719 - loss: 0.3410 - val_accuracy: 0.7541 - val_loss: 1.0942
# Epoch 483/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8743 - loss: 0.3204 - val_accuracy: 0.7459 - val_loss: 1.1763
# Epoch 484/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8751 - loss: 0.3240 - val_accuracy: 0.7541 - val_loss: 1.0371
# Epoch 485/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.8828 - loss: 0.3126 - val_accuracy: 0.7637 - val_loss: 1.0369
# Epoch 486/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8672 - loss: 0.3522 - val_accuracy: 0.7459 - val_loss: 1.1515
# Epoch 487/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8790 - loss: 0.3166 - val_accuracy: 0.7486 - val_loss: 1.1948
# Epoch 488/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8715 - loss: 0.3351 - val_accuracy: 0.7432 - val_loss: 1.2197
# Epoch 489/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8810 - loss: 0.2983 - val_accuracy: 0.7432 - val_loss: 1.1163
# Epoch 490/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8639 - loss: 0.3301 - val_accuracy: 0.7445 - val_loss: 1.1119
# Epoch 491/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8643 - loss: 0.3390 - val_accuracy: 0.7514 - val_loss: 1.2190
# Epoch 492/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.8647 - loss: 0.3554 - val_accuracy: 0.7596 - val_loss: 1.0545
# Epoch 493/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - accuracy: 0.8828 - loss: 0.2973 - val_accuracy: 0.7650 - val_loss: 1.0677
# Epoch 494/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8996 - loss: 0.2880 - val_accuracy: 0.7678 - val_loss: 1.1214
# Epoch 495/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8941 - loss: 0.2894 - val_accuracy: 0.7486 - val_loss: 1.3703
# Epoch 496/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.8808 - loss: 0.3084 - val_accuracy: 0.7637 - val_loss: 1.1014
# Epoch 497/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.8813 - loss: 0.3107 - val_accuracy: 0.7582 - val_loss: 1.1285
# Epoch 498/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8749 - loss: 0.3129 - val_accuracy: 0.7773 - val_loss: 1.1427
# Epoch 499/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.8764 - loss: 0.3290 - val_accuracy: 0.7568 - val_loss: 0.9836
# Epoch 500/500
# 92/92 ━━━━━━━━━━━━━━━━━━━━ 5s 33ms/step - accuracy: 0.8698 - loss: 0.3469 - val_accuracy: 0.7637 - val_loss: 1.1821

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# -----------------
# -----------------
# -----------------

# %% [markdown]
# -----------------
# -----------------
# -----------------

# %% [markdown]
# -----------------
# -----------------
# -----------------

# %% [markdown]
# ## Predict on new data

# %%
# !git clone https://github.com/radhakrishnan-omotec/fundus-repo.git
# Out:
# Cloning into 'fundus-repo'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 52 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (52/52), 33.35 MiB | 11.51 MiB/s, done.
# Resolving deltas: 100% (18/18), done.

# %% [markdown]
# Use your model to classify an image that wasn't included in the training or validation sets.

# %% [markdown]
# Note: Data augmentation and dropout layers are inactive at inference time.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        # Calculate confidence as a percentage
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/mild_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Mild'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 0024cdab0c1e.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        # Calculate confidence as a percentage
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/moderate_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Moderate'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 000c1434d8d7.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        # Calculate confidence as a percentage
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/No_DR_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/No_DR'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 002c21358ce6.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/Proliferate_DR_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Proliferate_DR'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 001639a390f0.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/Severe_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 0104b032c141.png with 100.00% confidence.

# %% [markdown]
# This code compares an uploaded image to each image in a dataset using Mean Squared Error to determine if they match, returning the filename of any matching image. It preprocesses images to a specified size and handles non-file entries and errors gracefully.

# %% [markdown]
# ## Use TensorFlow Lite
#
# TensorFlow Lite is a set of tools that enables on-device machine learning by helping developers run their models on mobile, embedded, and edge devices.

# %% [markdown]
# ### Convert the Keras Sequential model to a TensorFlow Lite model
#
# To use the trained model with on-device applications, first [convert it](https://www.tensorflow.org/lite/models/convert) to a smaller and more efficient model format called a [TensorFlow Lite](https://www.tensorflow.org/lite/) model.
#
# In this example, take the trained Keras Sequential model and use `tf.lite.TFLiteConverter.from_keras_model` to generate a [TensorFlow Lite](https://www.tensorflow.org/lite/) model:

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('model_fundus_level2.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpwndv8zy7'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name='keras_tensor_18')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   132055044405008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132055044402512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132055024311312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132055024306704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132055024314384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132055024317648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132055024315920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132055024305360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132055024314960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132055024310928: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# The TensorFlow Lite model you saved in the previous step can contain several function signatures. The Keras model converter API uses the default signature automatically. Learn more about [TensorFlow Lite signatures](https://www.tensorflow.org/lite/guide/signatures).

# %% [markdown]
# ### Run the TensorFlow Lite model
#
# You can access the TensorFlow Lite saved model signatures in Python via the `tf.lite.Interpreter` class.
#
# Load the model with the `Interpreter`:

# %%
TF_MODEL_FILE_PATH = 'model_fundus_level2.tflite' # The default path to the saved TensorFlow Lite model

interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)

# %% [markdown]
# Print the signatures from the converted model to obtain the names of the inputs (and outputs):

# %%
interpreter.get_signature_list()
# Out:
# {'serving_default': {'inputs': ['keras_tensor_18'], 'outputs': ['output_0']}}

# %% [markdown]
# In this example, you have one default signature called `serving_default`. In addition, the name of the `'inputs'` is `'sequential_1_input'`, while the `'outputs'` are called `'outputs'`. You can look up these first and last Keras layer names when running `Model.summary`, as demonstrated earlier in this tutorial.
#
# Now you can test the loaded TensorFlow Model by performing inference on a sample image with `tf.lite.Interpreter.get_signature_runner` by passing the signature name as follows:

# %%
classify_lite = interpreter.get_signature_runner('serving_default')
classify_lite

# %% [markdown]
# #  LOCAL TEST CODE (ONLY)

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode
from google.colab import files

# JavaScript to take a photo and return it as a base64 string
def take_photo(filename='photo.jpg', quality=0.8):
    js = Javascript('''
    async function takePhoto(quality) {
        const div = document.createElement('div');
        const capture = document.createElement('button');
        capture.textContent = 'Capture';
        document.body.appendChild(div);
        div.appendChild(capture);

        // Setup camera stream
        const video = document.createElement('video');
        video.style.display = 'block';
        const stream = await navigator.mediaDevices.getUserMedia({video: true});
        div.appendChild(video);
        video.srcObject = stream;
        await video.play();

        // Wait for capture button to be clicked
        await new Promise((resolve) => capture.onclick = resolve);

        // Capture photo
        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        canvas.getContext('2d').drawImage(video, 0, 0);
        stream.getTracks().forEach(track => track.stop());
        div.remove();
        return canvas.toDataURL('image/jpeg', quality);
    }
    ''')
    display(js)
    data = eval_js(f'takePhoto({quality})')
    binary = b64decode(data.split(',')[1])

    # Save the image locally
    with open(filename, 'wb') as f:
        f.write(binary)

    print(f"Saved photo to {filename}")

    return filename

# Capture a photo and save it
photo_filename = take_photo()

# %% [markdown]
# #Prediction Testing Phase

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil

# Define the destination folder in your Google Drive
drive_folder = '/content/drive/MyDrive/retinopathy fundus'

# Move the captured photo to Google Drive
shutil.move(photo_filename, drive_folder)

print(f"Moved {photo_filename} to {drive_folder}")
# Out:
# Moved photo.jpg to /content/drive/MyDrive/retinopathy fundus

# %%
image_path = '/content/fundus-repo/Proliferate_DR_retinopathy_test_image.png'  # Replace with your actual image path

# %% [markdown]
# # Prediction with webcam Fundus images

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Define the paths
image_path = '/content/fundus-repo/Proliferate_DR_retinopathy_test_image.png'  # Replace with your actual image path
TF_MODEL_FILE_PATH = 'model_fundus_level2.tflite'  # The default path to the saved TensorFlow Lite model

# Define class names corresponding to your model output
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = Image.open(img_path).convert('RGB')
    img = img.resize(target_size)
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# Preprocess the image
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (batch_size, height, width, channels)
image_data = load_and_preprocess_image(image_path, input_shape)

# Ensure the input tensor's type matches the model's expected type
input_data = image_data.astype(input_details[0]['dtype'])

# Set input tensor
interpreter.set_tensor(input_details[0]['index'], input_data)

# Run inference
interpreter.invoke()

# Get the output tensor
output_data = interpreter.get_tensor(output_details[0]['index'])

# Get predicted class index
predicted_class_index = np.argmax(output_data[0])
predicted_class_name = class_names[predicted_class_index]

print(f"Predicted class index: {predicted_class_index}")
print(f"Predicted class name: {predicted_class_name}")

# Show the image along with the prediction
img = Image.open(image_path)
plt.imshow(img)
plt.title(f"Predicted: {predicted_class_name}")
plt.axis('off')
plt.show()
# Out:
# Predicted class index: 1
# Predicted class name: Mild

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Define the paths
image_path = '/content/fundus-repo/mild_retinopathy_test_image.png'  # Replace with your actual image path
TF_MODEL_FILE_PATH = 'model_fundus_level2.tflite'  # The default path to the saved TensorFlow Lite model

# Define class names corresponding to your model output
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = Image.open(img_path).convert('RGB')
    img = img.resize(target_size)
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# Preprocess the image
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (batch_size, height, width, channels)
image_data = load_and_preprocess_image(image_path, input_shape)

# Ensure the input tensor's type matches the model's expected type
input_data = image_data.astype(input_details[0]['dtype'])

# Set input tensor
interpreter.set_tensor(input_details[0]['index'], input_data)

# Run inference
interpreter.invoke()

# Get the output tensor
output_data = interpreter.get_tensor(output_details[0]['index'])

# Get predicted class index
predicted_class_index = np.argmax(output_data[0])
predicted_class_name = class_names[predicted_class_index]

print(f"Predicted class index: {predicted_class_index}")
print(f"Predicted class name: {predicted_class_name}")

# Show the image along with the prediction
img = Image.open(image_path)
plt.imshow(img)
plt.title(f"Predicted: {predicted_class_name}")
plt.axis('off')
plt.show()
# Out:
# Predicted class index: 1
# Predicted class name: Mild

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Define the paths
image_path = '/content/fundus-repo/No_DR_retinopathy_test_image.png'  # Replace with your actual image path
TF_MODEL_FILE_PATH = 'model_fundus_level2.tflite'  # The default path to the saved TensorFlow Lite model

# Define class names corresponding to your model output
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = Image.open(img_path).convert('RGB')
    img = img.resize(target_size)
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# Preprocess the image
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (batch_size, height, width, channels)
image_data = load_and_preprocess_image(image_path, input_shape)

# Ensure the input tensor's type matches the model's expected type
input_data = image_data.astype(input_details[0]['dtype'])

# Set input tensor
interpreter.set_tensor(input_details[0]['index'], input_data)

# Run inference
interpreter.invoke()

# Get the output tensor
output_data = interpreter.get_tensor(output_details[0]['index'])

# Get predicted class index
predicted_class_index = np.argmax(output_data[0])
predicted_class_name = class_names[predicted_class_index]

print(f"Predicted class index: {predicted_class_index}")
print(f"Predicted class name: {predicted_class_name}")

# Show the image along with the prediction
img = Image.open(image_path)
plt.imshow(img)
plt.title(f"Predicted: {predicted_class_name}")
plt.axis('off')
plt.show()
# Out:
# Predicted class index: 1
# Predicted class name: Mild

# %% [markdown]
# Similar to what you did earlier in the tutorial, you can use the TensorFlow Lite model to classify images that weren't included in the training or validation sets.
#
# You have already tensorized that image and saved it as `img_array`. Now, pass it to the first argument (the name of the `'inputs'`) of the loaded TensorFlow Lite model (`predictions_lite`), compute softmax activations, and then print the prediction for the class with the highest computed probability.

# %% [markdown]
# Of the five classes—`'No_DR'`, `'Mild'`, `'Moderate'`, `' Severe'` and `'Proliferate_DR'`

# %% [markdown]
# #Prediction from Webcam Test Data

# %%
import tensorflow as tf
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
from google.colab import output
import time

# Define the TensorFlow Lite model path and class names
TF_MODEL_FILE_PATH = 'model_fundus_level2.tflite'  # Ensure the file is uploaded to the Colab environment
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Function to preprocess the frame
def preprocess_frame(frame, target_size):
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert from BGR to RGB
    img = cv2.resize(img, target_size)  # Resize to the target size
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array

# Get the model's input shape
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (height, width)

# Initialize webcam capture
def capture_frame():
    js = """
    async function captureWebcam() {
        const video = document.createElement('video');
        video.style.position = 'fixed';
        video.style.top = '0';
        video.style.left = '0';
        video.style.width = '100%';
        video.style.height = '100%';
        video.style.zIndex = '1000';
        document.body.appendChild(video);

        const stream = await navigator.mediaDevices.getUserMedia({ video: true });
        video.srcObject = stream;
        await video.play();

        const canvas = document.createElement('canvas');
        canvas.width = video.videoWidth;
        canvas.height = video.videoHeight;
        const ctx = canvas.getContext('2d');

        for (let i = 0; i < 100; i++) {
            ctx.drawImage(video, 0, 0, canvas.width, canvas.height);
            const imgData = canvas.toDataURL('image/jpeg');
            google.colab.kernel.invokeFunction('notebook.capture', [imgData], {});
            await new Promise(resolve => setTimeout(resolve, 100));
        }

        video.pause();
        stream.getTracks()[0].stop();
        document.body.removeChild(video);
    }
    captureWebcam();
    """
    output.eval_js(js)

# Callback to capture the frame from JS
def capture_callback(image_data):
    image_data = image_data.split(',')[1]  # Remove the ....frombuffer(base64.b64decode(image_data), np.uint8)
    frame = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
    return frame

# Register the callback function
output.register_callback('notebook.capture', capture_callback)

print("Starting webcam. Please allow camera access.")
capture_frame()

# Start processing the frames
while True:
    ret, frame = cap.read()  # Frame bytes if isn't>

# %%
import base64
from google.colab import output
import cv2

# Function to preprocess and predict the class from a frame
def preprocess_and_predict(frame):
    # Preprocess the frame
    input_data = preprocess_frame(frame, input_shape).astype(input_details[0]['dtype'])

    # Set input tensor
    interpreter.set_tensor(input_details[0]['index'], input_data)

    # Run inference
    interpreter.invoke()

    # Get the output tensor
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # Get predicted class index and name
    predicted_class_index = np.argmax(output_data[0])
    predicted_class_name = class_names[predicted_class_index]

    return predicted_class_name

# Main function to capture and process frames
def capture_frame():
    js_code = """
        async function captureWebcam() {
            const video = document.createElement('video');
            video.style.display = 'none';
            document.body.appendChild(video);

            const stream = await navigator.mediaDevices.getUserMedia({ video: true });
            video.srcObject = stream;
            await video.play();

            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            const ctx = canvas.getContext('2d');

            for (let i = 0; i < 1; i++) {
                ctx.drawImage(video, 0, 0, canvas.width, canvas.height);
                const imageData = canvas.toDataURL('image/jpeg');
                google.colab.kernel.invokeFunction('notebook.capture_frame', [imageData], {});
                await new Promise(resolve => setTimeout(resolve, 1000));
            }

            stream.getTracks()[0].stop();
            document.body.removeChild(video);
        }
        captureWebcam();
    """
    output.eval_js(js_code)

# Callback function to handle the frame data from JavaScript
def handle_frame(data):
    # Decode the base64-encoded image
    image_data = data.split(',')[1]
    image_bytes = base64.b64decode(image_data)
    nparr = np.frombuffer(image_bytes, np.uint8)
    frame = cv2.imdecode(nparr, cv2.IMREAD_COLOR)

    # Process the frame and get prediction
    predicted_class_name = preprocess_and_predict(frame)

    # Display the result
    cv2_imshow(frame)
    print(f"Prediction: {predicted_class_name}")

# Register the callback function for frame capture
output.register_callback('notebook.capture_frame', handle_frame)

# Capture and process frames
print("Starting webcam. Please allow camera access.")
capture_frame()
# Out:
# Starting webcam. Please allow camera access.

# %% [markdown]
# #Standalone Code to test in RPI 5

# %%
import tensorflow as tf
import numpy as np
import cv2
from PIL import Image
import matplotlib.pyplot as plt

# Define the TensorFlow Lite model path and class names
TF_MODEL_FILE_PATH = 'model_fundus_level2.tflite'  # The default path to the saved TensorFlow Lite model
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Function to preprocess the frame
def preprocess_frame(frame, target_size):
    img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert from BGR to RGB
    img = cv2.resize(img, target_size)  # Resize to the target size
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array

# Get the model's input shape
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (height, width)

# Access the webcam
cap = cv2.VideoCapture(0)  # Open the default camera (change the index if needed)

if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

print("Press 'q' to quit.")

while True:
    ret, frame = cap.read()  # Capture a frame from the webcam
    if not ret:
        print("Error: Failed to capture image.")
        break

    # Preprocess the frame
    input_data = preprocess_frame(frame, input_shape)

    # Ensure the input tensor's type matches the model's expected type
    input_data = input_data.astype(input_details[0]['dtype'])

    # Set input tensor
    interpreter.set_tensor(input_details[0]['index'], input_data)

    # Run inference
    interpreter.invoke()

    # Get the output tensor
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # Get predicted class index and name
    predicted_class_index = np.argmax(output_data[0])
    predicted_class_name = class_names[predicted_class_index]

    # Display the prediction on the frame
    cv2.putText(
        frame,
        f"Prediction: {predicted_class_name}",
        (10, 30),
        cv2.FONT_HERSHEY_SIMPLEX,
        1,
        (0, 255, 0),
        2
    )

    # Show the frame with prediction
    cv2.imshow("Webcam Feed", frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Error: Could not open webcam.
# Press 'q' to quit.
# Error: Failed to capture image.

# %% [markdown]
# TESTING WITH WEBCAMERA:

# %%
import base64
from google.colab import output
import cv2
import time
import numpy as np

# Function to preprocess and predict the class from a frame
def preprocess_and_predict(frame):
    # Preprocess the frame
    input_data = preprocess_frame(frame, input_shape).astype(input_details[0]['dtype'])

    # Set input tensor
    interpreter.set_tensor(input_details[0]['index'], input_data)

    # Run inference
    interpreter.invoke()

    # Get the output tensor
    output_data = interpreter.get_tensor(output_details[0]['index'])

    # Get predicted class index and name
    predicted_class_index = np.argmax(output_data[0])
    predicted_class_name = class_names[predicted_class_index]

    return predicted_class_name

# Main function to capture and process frames
def capture_frame():
    js_code = """
        async function captureWebcam() {
            const video = document.createElement('video');
            video.style.display = 'none';
            document.body.appendChild(video);

            const stream = await navigator.mediaDevices.getUserMedia({ video: true });
            video.srcObject = stream;
            await video.play();

            const canvas = document.createElement('canvas');
            canvas.width = video.videoWidth;
            canvas.height = video.videoHeight;
            const ctx = canvas.getContext('2d');

            console.log("Webcam is ON. Capturing image in 10 seconds...");

            await new Promise(resolve => setTimeout(resolve, 10000)); // Wait for 10 seconds

            ctx.drawImage(video, 0, 0, canvas.width, canvas.height);
            const imageData = canvas.toDataURL('image/jpeg');
            google.colab.kernel.invokeFunction('notebook.capture_frame', [imageData], {});

            stream.getTracks()[0].stop();
            document.body.removeChild(video);
        }
        captureWebcam();
    """
    output.eval_js(js_code)

# Callback function to handle the frame data from JavaScript
def handle_frame(data):
    # Decode the base64-encoded image
    image_data = data.split(',')[1]
    image_bytes = base64.b64decode(image_data)
    nparr = np.frombuffer(image_bytes, np.uint8)
    frame = cv2.imdecode(nparr, cv2.IMREAD_COLOR)

    # Process the frame and get prediction
    predicted_class_name = preprocess_and_predict(frame)

    # Display the result
    cv2_imshow(frame)
    print(f"Prediction: {predicted_class_name}")

# Register the callback function for frame capture
output.register_callback('notebook.capture_frame', handle_frame)

# Capture and process frames
print("Starting webcam. Please allow camera access.")
capture_frame()
# Out:
# Starting webcam. Please allow camera access.
