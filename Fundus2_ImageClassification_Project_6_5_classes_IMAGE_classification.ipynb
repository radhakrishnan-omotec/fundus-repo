# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/fundus-repo/blob/main/Fundus2_ImageClassification_Project_6_5_classes_IMAGE_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Image classification

# %% [markdown]
# This tutorial shows how to classify images of flowers using a `tf.keras.Sequential` model and load data using `tf.keras.utils.image_dataset_from_directory`. It demonstrates the following concepts:
#
#
# * Efficiently loading a dataset off disk.
# * Identifying overfitting and applying techniques to mitigate it, including data augmentation and dropout.
#
# This tutorial follows a basic machine learning workflow:
#
# 1. Examine and understand data
# 2. Build an input pipeline
# 3. Build the model
# 4. Train the model
# 5. Test the model
# 6. Improve the model and repeat the process

# %%
# !pip install -q kaggle

# !mkdir -p ~/.kaggle

# !cp kaggle.json ~/.kaggle/

# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle competitions download -c diabetic-retinopathy-detection

# !kaggle datasets download -d sovitrath/diabetic-retinopathy-224x224-gaussian-filtered
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/__init__.py", line 7, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.11/dist-packages/kaggle/api/kaggle_api_extended.py", line 407, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method. See setup instructions at https://github.com/Kaggle/kaggle-api/
# Dataset URL: https://www.kaggle.com/datasets/sovitrath/diabetic-retinopathy-224x224-gaussian-filtered
# License(s): CC0-1.0
# Downloading diabetic-retinopathy-224x224-gaussian-filtered.zip to /content
#  98% 418M/427M [00:04<00:00, 97.9MB/s]
# 100% 427M/427M [00:04<00:00, 96.4MB/s]

# %% [markdown]
# ## Setup
#
# Import TensorFlow and other necessary libraries:

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Download and explore the dataset

# %% [markdown]
# This uses a dataset of about 3,700 photos of eyes. The dataset contains five sub-directories, one per class:
#
# ```
# gaussian_filtered_images/
#   No_DR/
#   Mild/
#   Moderate/
#   Severe/
#   Proliferate_DR/
# ```

# %%
# Unzip the competition data
# !unzip -q diabetic-retinopathy-detection.zip -d diabetic-retinopathy-detection

# Unzip the dataset
# !unzip -q diabetic-retinopathy-224x224-gaussian-filtered.zip -d diabetic-retinopathy-224x224-gaussian-filtered
# Out:
# unzip:  cannot find or open diabetic-retinopathy-detection.zip, diabetic-retinopathy-detection.zip.zip or diabetic-retinopathy-detection.zip.ZIP.

# %% [markdown]
# After downloading, you should now have a copy of the dataset available. There are 3,670 total images:

# %%
import pathlib
# Define the directory path
data_dir = pathlib.Path('/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images')
# Specify the image file extensions to look for
image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}
# Use pathlib to find all image files in the directory and subdirectories
image_files = [f for f in data_dir.rglob('*') if f.suffix.lower() in image_extensions]
# Count the number of image files
num_images = len(image_files)
print(f"Number of images: {num_images}")
# Out:
# Number of images: 3662

# %% [markdown]
# ## Load data using a Keras utility
#
# Next, load these images off disk using the helpful `tf.keras.utils.image_dataset_from_directory` utility. This will take you from a directory of images on disk to a `tf.data.Dataset` in just a couple lines of code. If you like, you can also write your own data loading code from scratch by visiting the [Load and preprocess images](../load_data/images.ipynb) tutorial.

# %% [markdown]
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# It's good practice to use a validation split when developing your model. Use 80% of the images for training and 20% for validation.

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.1,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3662 files belonging to 5 classes.
# Using 3296 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.1,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3662 files belonging to 5 classes.
# Using 366 files for validation.

# %% [markdown]
# You can find the class names in the `class_names` attribute on these datasets. These correspond to the directory names in alphabetical order.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Mild', 'Moderate', 'No_DR', 'Proliferate_DR', 'Severe']

# %% [markdown]
# ## Visualize the data
#
# Here are the first nine images from the training dataset:

# %%
plt.figure(figsize=(16, 16))
for images, labels in train_ds.take(1):
  for i in range(25):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# You will pass these datasets to the Keras `Model.fit` method for training later in this tutorial. If you like, you can also manually iterate over the dataset and retrieve batches of images:

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.
#
# You can call `.numpy()` on the `image_batch` and `labels_batch` tensors to convert them to a `numpy.ndarray`.

# %% [markdown]
# ## Configure the dataset for performance
#
# Make sure to use buffered prefetching, so you can yield data from disk without having I/O become blocking. These are two important methods you should use when loading data:
#
# - `Dataset.cache` keeps the images in memory after they're loaded off disk during the first epoch. This will ensure the dataset does not become a bottleneck while training your model. If your dataset is too large to fit into memory, you can also use this method to create a performant on-disk cache.
# - `Dataset.prefetch` overlaps data preprocessing and model execution while training.
#
# Interested readers can learn more about both methods, as well as how to cache data to disk in the *Prefetching* section of the [Better performance with the tf.data API](../../guide/data_performance.ipynb) guide.

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## Standardize the data

# %% [markdown]
# The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network; in general you should seek to make your input values small.
#
# Here, you will standardize values to be in the `[0, 1]` range by using `tf.keras.layers.Rescaling`:

# %%
normalization_layer = layers.Rescaling(1./255)

# %% [markdown]
# There are two ways to use this layer. You can apply it to the dataset by calling `Dataset.map`:

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %% [markdown]
# Or, you can include the layer inside your model definition, which can simplify deployment. Use the second approach here.

# %% [markdown]
# Note: You previously resized images using the `image_size` argument of `tf.keras.utils.image_dataset_from_directory`. If you want to include the resizing logic in your model as well, you can use the `tf.keras.layers.Resizing` layer.

# %% [markdown]
# ## A basic Keras model
#
# ### Create the model
#
# The Keras [Sequential](https://www.tensorflow.org/guide/keras/sequential_model) model consists of three convolution blocks (`tf.keras.layers.Conv2D`) with a max pooling layer (`tf.keras.layers.MaxPooling2D`) in each of them. There's a fully-connected layer (`tf.keras.layers.Dense`) with 128 units on top of it that is activated by a ReLU activation function (`'relu'`). This model has not been tuned for high accuracy; the goal of this tutorial is to show a standard approach.

# %%
num_classes = len(class_names)
model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ### Compile the model
#
# For this tutorial, choose the `tf.keras.optimizers.Adam` optimizer and `tf.keras.losses.SparseCategoricalCrossentropy` loss function. To view training and validation accuracy for each training epoch, pass the `metrics` argument to `Model.compile`.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Model summary
#
# View all the layers of the network using the Keras `Model.summary` method:

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_1 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 30976)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       3,965,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,989,285 (15.22 MB)
#  Trainable params: 3,989,285 (15.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Train the model

# %% [markdown]
# Train the model for 20 epochs with the Keras `Model.fit` method:

# %%
epochs=200
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.5366 - loss: 1.2794 - val_accuracy: 0.7459 - val_loss: 0.7347
# Epoch 2/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7028 - loss: 0.8120 - val_accuracy: 0.7158 - val_loss: 0.7168
# Epoch 3/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7169 - loss: 0.7683 - val_accuracy: 0.7213 - val_loss: 0.7561
# Epoch 4/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7244 - loss: 0.7415 - val_accuracy: 0.7404 - val_loss: 0.6901
# Epoch 5/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7376 - loss: 0.6872 - val_accuracy: 0.7541 - val_loss: 0.6753
# Epoch 6/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7614 - loss: 0.6478 - val_accuracy: 0.7377 - val_loss: 0.7108
# Epoch 7/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7696 - loss: 0.6110 - val_accuracy: 0.7568 - val_loss: 0.6831
# Epoch 8/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7895 - loss: 0.5711 - val_accuracy: 0.7514 - val_loss: 0.7072
# Epoch 9/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7936 - loss: 0.5648 - val_accuracy: 0.7459 - val_loss: 0.7022
# Epoch 10/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8166 - loss: 0.4704 - val_accuracy: 0.7295 - val_loss: 0.7311
# Epoch 11/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8427 - loss: 0.4268 - val_accuracy: 0.7158 - val_loss: 0.7723
# Epoch 12/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8652 - loss: 0.3453 - val_accuracy: 0.7459 - val_loss: 0.7405
# Epoch 13/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8790 - loss: 0.3211 - val_accuracy: 0.7541 - val_loss: 0.8397
# Epoch 14/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8933 - loss: 0.2706 - val_accuracy: 0.7377 - val_loss: 0.8062
# Epoch 15/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9205 - loss: 0.2172 - val_accuracy: 0.7568 - val_loss: 0.8368
# Epoch 16/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9379 - loss: 0.1892 - val_accuracy: 0.7322 - val_loss: 1.0268
# Epoch 17/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9516 - loss: 0.1464 - val_accuracy: 0.7404 - val_loss: 0.9224
# Epoch 18/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9579 - loss: 0.1554 - val_accuracy: 0.7514 - val_loss: 1.0897
# Epoch 19/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9697 - loss: 0.1050 - val_accuracy: 0.7486 - val_loss: 1.1055
# Epoch 20/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9750 - loss: 0.0955 - val_accuracy: 0.7377 - val_loss: 1.4557
# Epoch 21/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9791 - loss: 0.0787 - val_accuracy: 0.7377 - val_loss: 1.3192
# Epoch 22/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9790 - loss: 0.0897 - val_accuracy: 0.7295 - val_loss: 0.9255
# Epoch 23/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9774 - loss: 0.0958 - val_accuracy: 0.7514 - val_loss: 1.2218
# Epoch 24/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9868 - loss: 0.0573 - val_accuracy: 0.7295 - val_loss: 1.3357
# Epoch 25/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9845 - loss: 0.0664 - val_accuracy: 0.7377 - val_loss: 1.3047
# Epoch 26/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9865 - loss: 0.0555 - val_accuracy: 0.7432 - val_loss: 1.2797
# Epoch 27/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9896 - loss: 0.0423 - val_accuracy: 0.7404 - val_loss: 1.2892
# Epoch 28/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9854 - loss: 0.0489 - val_accuracy: 0.7650 - val_loss: 1.4624
# Epoch 29/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9892 - loss: 0.0451 - val_accuracy: 0.7404 - val_loss: 1.5270
# Epoch 30/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9856 - loss: 0.0491 - val_accuracy: 0.7432 - val_loss: 1.4928
# Epoch 31/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9890 - loss: 0.0455 - val_accuracy: 0.7350 - val_loss: 1.5998
# Epoch 32/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9863 - loss: 0.0531 - val_accuracy: 0.7459 - val_loss: 1.1394
# Epoch 33/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9876 - loss: 0.0475 - val_accuracy: 0.7432 - val_loss: 1.7036
# Epoch 34/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9864 - loss: 0.0512 - val_accuracy: 0.7459 - val_loss: 1.3131
# Epoch 35/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9863 - loss: 0.0353 - val_accuracy: 0.7541 - val_loss: 1.2357
# Epoch 36/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9892 - loss: 0.0303 - val_accuracy: 0.7486 - val_loss: 1.6540
# Epoch 37/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9907 - loss: 0.0337 - val_accuracy: 0.7459 - val_loss: 1.3716
# Epoch 38/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9852 - loss: 0.0359 - val_accuracy: 0.7568 - val_loss: 1.4641
# Epoch 39/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9898 - loss: 0.0316 - val_accuracy: 0.7432 - val_loss: 1.3858
# Epoch 40/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9824 - loss: 0.0492 - val_accuracy: 0.7459 - val_loss: 1.4876
# Epoch 41/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9853 - loss: 0.0425 - val_accuracy: 0.7541 - val_loss: 1.1847
# Epoch 42/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9891 - loss: 0.0392 - val_accuracy: 0.7486 - val_loss: 1.4043
# Epoch 43/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9868 - loss: 0.0368 - val_accuracy: 0.7377 - val_loss: 1.5079
# Epoch 44/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9886 - loss: 0.0311 - val_accuracy: 0.7404 - val_loss: 1.2753
# Epoch 45/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9923 - loss: 0.0284 - val_accuracy: 0.7459 - val_loss: 1.3788
# Epoch 46/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9886 - loss: 0.0296 - val_accuracy: 0.7459 - val_loss: 1.4698
# Epoch 47/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9886 - loss: 0.0352 - val_accuracy: 0.7459 - val_loss: 1.4117
# Epoch 48/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9874 - loss: 0.0416 - val_accuracy: 0.7568 - val_loss: 1.4237
# Epoch 49/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9880 - loss: 0.0289 - val_accuracy: 0.7486 - val_loss: 1.4132
# Epoch 50/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9911 - loss: 0.0235 - val_accuracy: 0.7404 - val_loss: 1.4099
# Epoch 51/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9870 - loss: 0.0267 - val_accuracy: 0.7623 - val_loss: 1.5221
# Epoch 52/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9890 - loss: 0.0324 - val_accuracy: 0.7322 - val_loss: 1.4736
# Epoch 53/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9900 - loss: 0.0248 - val_accuracy: 0.7514 - val_loss: 1.5487
# Epoch 54/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9893 - loss: 0.0256 - val_accuracy: 0.7432 - val_loss: 1.4281
# Epoch 55/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9872 - loss: 0.0318 - val_accuracy: 0.7596 - val_loss: 1.4894
# Epoch 56/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9889 - loss: 0.0337 - val_accuracy: 0.7432 - val_loss: 1.5060
# Epoch 57/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9882 - loss: 0.0312 - val_accuracy: 0.7596 - val_loss: 1.3326
# Epoch 58/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9845 - loss: 0.0364 - val_accuracy: 0.7404 - val_loss: 1.4662
# Epoch 59/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9886 - loss: 0.0253 - val_accuracy: 0.7623 - val_loss: 1.4346
# Epoch 60/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9910 - loss: 0.0256 - val_accuracy: 0.7459 - val_loss: 1.2848
# Epoch 61/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9860 - loss: 0.0334 - val_accuracy: 0.7404 - val_loss: 1.3314
# Epoch 62/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9830 - loss: 0.0546 - val_accuracy: 0.7322 - val_loss: 1.6379
# Epoch 63/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9906 - loss: 0.0252 - val_accuracy: 0.7514 - val_loss: 1.3418
# Epoch 64/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9883 - loss: 0.0339 - val_accuracy: 0.7678 - val_loss: 1.6937
# Epoch 65/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9924 - loss: 0.0237 - val_accuracy: 0.7459 - val_loss: 1.6215
# Epoch 66/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9850 - loss: 0.0365 - val_accuracy: 0.7486 - val_loss: 1.4608
# Epoch 67/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9883 - loss: 0.0288 - val_accuracy: 0.7486 - val_loss: 1.6699
# Epoch 68/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9891 - loss: 0.0226 - val_accuracy: 0.7705 - val_loss: 1.7523
# Epoch 69/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9891 - loss: 0.0254 - val_accuracy: 0.7650 - val_loss: 1.6101
# Epoch 70/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9882 - loss: 0.0312 - val_accuracy: 0.7596 - val_loss: 1.4293
# Epoch 71/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9890 - loss: 0.0272 - val_accuracy: 0.7486 - val_loss: 1.7164
# Epoch 72/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9905 - loss: 0.0208 - val_accuracy: 0.7514 - val_loss: 1.4010
# Epoch 73/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9883 - loss: 0.0298 - val_accuracy: 0.7596 - val_loss: 1.5559
# Epoch 74/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9868 - loss: 0.0285 - val_accuracy: 0.7541 - val_loss: 1.3292
# Epoch 75/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9860 - loss: 0.0319 - val_accuracy: 0.7486 - val_loss: 1.4899
# Epoch 76/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9889 - loss: 0.0275 - val_accuracy: 0.7596 - val_loss: 1.5629
# Epoch 77/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9887 - loss: 0.0216 - val_accuracy: 0.7596 - val_loss: 1.5409
# Epoch 78/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9853 - loss: 0.0306 - val_accuracy: 0.7568 - val_loss: 1.4052
# Epoch 79/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9895 - loss: 0.0183 - val_accuracy: 0.7568 - val_loss: 1.5900
# Epoch 80/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9879 - loss: 0.0213 - val_accuracy: 0.7568 - val_loss: 1.4721
# Epoch 81/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9876 - loss: 0.0236 - val_accuracy: 0.7541 - val_loss: 1.5919
# Epoch 82/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9864 - loss: 0.0267 - val_accuracy: 0.7596 - val_loss: 1.4245
# Epoch 83/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9867 - loss: 0.0239 - val_accuracy: 0.7650 - val_loss: 1.8996
# Epoch 84/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9899 - loss: 0.0221 - val_accuracy: 0.7514 - val_loss: 1.7544
# Epoch 85/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9882 - loss: 0.0233 - val_accuracy: 0.7541 - val_loss: 1.6875
# Epoch 86/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9911 - loss: 0.0228 - val_accuracy: 0.7459 - val_loss: 1.5935
# Epoch 87/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9894 - loss: 0.0215 - val_accuracy: 0.7596 - val_loss: 1.7619
# Epoch 88/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9910 - loss: 0.0156 - val_accuracy: 0.7678 - val_loss: 1.4491
# Epoch 89/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9907 - loss: 0.0189 - val_accuracy: 0.7623 - val_loss: 1.4791
# Epoch 90/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9870 - loss: 0.0234 - val_accuracy: 0.7596 - val_loss: 1.4886
# Epoch 91/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9863 - loss: 0.0236 - val_accuracy: 0.7486 - val_loss: 1.3526
# Epoch 92/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9874 - loss: 0.0213 - val_accuracy: 0.7732 - val_loss: 1.5137
# Epoch 93/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9880 - loss: 0.0224 - val_accuracy: 0.7650 - val_loss: 1.6070
# Epoch 94/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9911 - loss: 0.0151 - val_accuracy: 0.7459 - val_loss: 1.3917
# Epoch 95/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9861 - loss: 0.0208 - val_accuracy: 0.7596 - val_loss: 1.5509
# Epoch 96/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9864 - loss: 0.0237 - val_accuracy: 0.7568 - val_loss: 1.6440
# Epoch 97/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9902 - loss: 0.0192 - val_accuracy: 0.7514 - val_loss: 1.5747
# Epoch 98/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9871 - loss: 0.0218 - val_accuracy: 0.7650 - val_loss: 1.6513
# Epoch 99/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9880 - loss: 0.0242 - val_accuracy: 0.7541 - val_loss: 1.6422
# Epoch 100/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9884 - loss: 0.0182 - val_accuracy: 0.7514 - val_loss: 1.9365
# Epoch 101/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9854 - loss: 0.0209 - val_accuracy: 0.7514 - val_loss: 1.5180
# Epoch 102/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9879 - loss: 0.0213 - val_accuracy: 0.7459 - val_loss: 1.5548
# Epoch 103/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9867 - loss: 0.0212 - val_accuracy: 0.7678 - val_loss: 1.7497
# Epoch 104/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9873 - loss: 0.0226 - val_accuracy: 0.7514 - val_loss: 1.6128
# Epoch 105/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9830 - loss: 0.0262 - val_accuracy: 0.7432 - val_loss: 1.4719
# Epoch 106/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9907 - loss: 0.0171 - val_accuracy: 0.7459 - val_loss: 1.4688
# Epoch 107/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9878 - loss: 0.0223 - val_accuracy: 0.7486 - val_loss: 1.7520
# Epoch 108/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9889 - loss: 0.0203 - val_accuracy: 0.7377 - val_loss: 1.3887
# Epoch 109/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9891 - loss: 0.0185 - val_accuracy: 0.7404 - val_loss: 1.3773
# Epoch 110/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9886 - loss: 0.0191 - val_accuracy: 0.7404 - val_loss: 1.4248
# Epoch 111/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9870 - loss: 0.0210 - val_accuracy: 0.7459 - val_loss: 1.8177
# Epoch 112/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9879 - loss: 0.0236 - val_accuracy: 0.7377 - val_loss: 1.6861
# Epoch 113/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9871 - loss: 0.0218 - val_accuracy: 0.7596 - val_loss: 1.5821
# Epoch 114/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9902 - loss: 0.0182 - val_accuracy: 0.7541 - val_loss: 1.5345
# Epoch 115/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9902 - loss: 0.0178 - val_accuracy: 0.7568 - val_loss: 1.4266
# Epoch 116/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9917 - loss: 0.0156 - val_accuracy: 0.7432 - val_loss: 1.5639
# Epoch 117/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9887 - loss: 0.0190 - val_accuracy: 0.7650 - val_loss: 1.6436
# Epoch 118/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9874 - loss: 0.0170 - val_accuracy: 0.7596 - val_loss: 1.5892
# Epoch 119/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9884 - loss: 0.0148 - val_accuracy: 0.7486 - val_loss: 1.4615
# Epoch 120/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9884 - loss: 0.0202 - val_accuracy: 0.7295 - val_loss: 1.9983
# Epoch 121/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9863 - loss: 0.0257 - val_accuracy: 0.7295 - val_loss: 1.4577
# Epoch 122/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9879 - loss: 0.0292 - val_accuracy: 0.7404 - val_loss: 2.7823
# Epoch 123/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9845 - loss: 0.0277 - val_accuracy: 0.7213 - val_loss: 1.7305
# Epoch 124/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9908 - loss: 0.0120 - val_accuracy: 0.7240 - val_loss: 1.4070
# Epoch 125/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9875 - loss: 0.0235 - val_accuracy: 0.7459 - val_loss: 1.6517
# Epoch 126/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9879 - loss: 0.0174 - val_accuracy: 0.7432 - val_loss: 1.7951
# Epoch 127/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9892 - loss: 0.0153 - val_accuracy: 0.7432 - val_loss: 1.7338
# Epoch 128/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9900 - loss: 0.0150 - val_accuracy: 0.7459 - val_loss: 1.6111
# Epoch 129/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9897 - loss: 0.0147 - val_accuracy: 0.7432 - val_loss: 1.7604
# Epoch 130/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9920 - loss: 0.0131 - val_accuracy: 0.7432 - val_loss: 1.5956
# Epoch 131/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9843 - loss: 0.0184 - val_accuracy: 0.7459 - val_loss: 1.7963
# Epoch 132/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9893 - loss: 0.0146 - val_accuracy: 0.7350 - val_loss: 1.6657
# Epoch 133/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9890 - loss: 0.0151 - val_accuracy: 0.7404 - val_loss: 1.6580
# Epoch 134/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9910 - loss: 0.0138 - val_accuracy: 0.7432 - val_loss: 1.6350
# Epoch 135/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9903 - loss: 0.0132 - val_accuracy: 0.7377 - val_loss: 1.7187
# Epoch 136/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9876 - loss: 0.0171 - val_accuracy: 0.7459 - val_loss: 1.6677
# Epoch 137/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9859 - loss: 0.0187 - val_accuracy: 0.7404 - val_loss: 1.8232
# Epoch 138/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9876 - loss: 0.0170 - val_accuracy: 0.7404 - val_loss: 1.4394
# Epoch 139/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9876 - loss: 0.0175 - val_accuracy: 0.7377 - val_loss: 1.6996
# Epoch 140/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9886 - loss: 0.0319 - val_accuracy: 0.7432 - val_loss: 1.4542
# Epoch 141/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9895 - loss: 0.0188 - val_accuracy: 0.7268 - val_loss: 1.9167
# Epoch 142/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9890 - loss: 0.0233 - val_accuracy: 0.7268 - val_loss: 1.8582
# Epoch 143/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9841 - loss: 0.0299 - val_accuracy: 0.7295 - val_loss: 2.0011
# Epoch 144/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9886 - loss: 0.0235 - val_accuracy: 0.7486 - val_loss: 1.7549
# Epoch 145/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9909 - loss: 0.0157 - val_accuracy: 0.7486 - val_loss: 1.6339
# Epoch 146/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9903 - loss: 0.0145 - val_accuracy: 0.7568 - val_loss: 1.6613
# Epoch 147/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9870 - loss: 0.0192 - val_accuracy: 0.7459 - val_loss: 1.6818
# Epoch 148/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9897 - loss: 0.0154 - val_accuracy: 0.7404 - val_loss: 1.8581
# Epoch 149/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9876 - loss: 0.0171 - val_accuracy: 0.7514 - val_loss: 1.6448
# Epoch 150/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9870 - loss: 0.0189 - val_accuracy: 0.7541 - val_loss: 1.6907
# Epoch 151/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9870 - loss: 0.0174 - val_accuracy: 0.7486 - val_loss: 1.6983
# Epoch 152/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9868 - loss: 0.0168 - val_accuracy: 0.7568 - val_loss: 1.6953
# Epoch 153/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9889 - loss: 0.0149 - val_accuracy: 0.7568 - val_loss: 1.6877
# Epoch 154/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9861 - loss: 0.0145 - val_accuracy: 0.7514 - val_loss: 1.7778
# Epoch 155/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9924 - loss: 0.0128 - val_accuracy: 0.7541 - val_loss: 1.7338
# Epoch 156/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9857 - loss: 0.0155 - val_accuracy: 0.7432 - val_loss: 1.6975
# Epoch 157/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9875 - loss: 0.0163 - val_accuracy: 0.7541 - val_loss: 1.7399
# Epoch 158/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9918 - loss: 0.0131 - val_accuracy: 0.7459 - val_loss: 1.6497
# Epoch 159/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9881 - loss: 0.0163 - val_accuracy: 0.7459 - val_loss: 1.7532
# Epoch 160/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9842 - loss: 0.0191 - val_accuracy: 0.7486 - val_loss: 1.7591
# Epoch 161/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9874 - loss: 0.0146 - val_accuracy: 0.7404 - val_loss: 1.7422
# Epoch 162/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9902 - loss: 0.0119 - val_accuracy: 0.7404 - val_loss: 1.8567
# Epoch 163/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9883 - loss: 0.0164 - val_accuracy: 0.7459 - val_loss: 1.6921
# Epoch 164/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9870 - loss: 0.0201 - val_accuracy: 0.7268 - val_loss: 2.0380
# Epoch 165/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9880 - loss: 0.0224 - val_accuracy: 0.7404 - val_loss: 1.6866
# Epoch 166/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9903 - loss: 0.0228 - val_accuracy: 0.7377 - val_loss: 1.4594
# Epoch 167/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9868 - loss: 0.0254 - val_accuracy: 0.7596 - val_loss: 1.6442
# Epoch 168/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9906 - loss: 0.0146 - val_accuracy: 0.7596 - val_loss: 1.7267
# Epoch 169/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9929 - loss: 0.0135 - val_accuracy: 0.7459 - val_loss: 1.5324
# Epoch 170/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9880 - loss: 0.0162 - val_accuracy: 0.7514 - val_loss: 1.7319
# Epoch 171/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9875 - loss: 0.0175 - val_accuracy: 0.7650 - val_loss: 1.6139
# Epoch 172/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9883 - loss: 0.0134 - val_accuracy: 0.7568 - val_loss: 1.6701
# Epoch 173/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9883 - loss: 0.0150 - val_accuracy: 0.7486 - val_loss: 1.5540
# Epoch 174/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9899 - loss: 0.0146 - val_accuracy: 0.7623 - val_loss: 1.7653
# Epoch 175/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9900 - loss: 0.0144 - val_accuracy: 0.7541 - val_loss: 1.8539
# Epoch 176/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9922 - loss: 0.0127 - val_accuracy: 0.7596 - val_loss: 1.8359
# Epoch 177/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9882 - loss: 0.0129 - val_accuracy: 0.7596 - val_loss: 1.7840
# Epoch 178/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9898 - loss: 0.0157 - val_accuracy: 0.7514 - val_loss: 1.8373
# Epoch 179/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9874 - loss: 0.0163 - val_accuracy: 0.7486 - val_loss: 1.7106
# Epoch 180/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9909 - loss: 0.0153 - val_accuracy: 0.7486 - val_loss: 1.6748
# Epoch 181/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9898 - loss: 0.0164 - val_accuracy: 0.7568 - val_loss: 1.8541
# Epoch 182/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9882 - loss: 0.0139 - val_accuracy: 0.7596 - val_loss: 1.8124
# Epoch 183/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9908 - loss: 0.0140 - val_accuracy: 0.7514 - val_loss: 1.8463
# Epoch 184/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9872 - loss: 0.0160 - val_accuracy: 0.7459 - val_loss: 1.8003
# Epoch 185/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9878 - loss: 0.0148 - val_accuracy: 0.7568 - val_loss: 1.8356
# Epoch 186/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9872 - loss: 0.0169 - val_accuracy: 0.7541 - val_loss: 1.8187
# Epoch 187/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9918 - loss: 0.0111 - val_accuracy: 0.7596 - val_loss: 1.8873
# Epoch 188/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9866 - loss: 0.0176 - val_accuracy: 0.7568 - val_loss: 1.9893
# Epoch 189/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9875 - loss: 0.0170 - val_accuracy: 0.7377 - val_loss: 1.4840
# Epoch 190/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9857 - loss: 0.0176 - val_accuracy: 0.7404 - val_loss: 2.0393
# Epoch 191/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9893 - loss: 0.0183 - val_accuracy: 0.7486 - val_loss: 1.8801
# Epoch 192/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9870 - loss: 0.0185 - val_accuracy: 0.7350 - val_loss: 2.0146
# Epoch 193/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9883 - loss: 0.0189 - val_accuracy: 0.7459 - val_loss: 1.7229
# Epoch 194/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9900 - loss: 0.0155 - val_accuracy: 0.7541 - val_loss: 1.6496
# Epoch 195/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9869 - loss: 0.0203 - val_accuracy: 0.7650 - val_loss: 1.8657
# Epoch 196/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9855 - loss: 0.0185 - val_accuracy: 0.7377 - val_loss: 2.0057
# Epoch 197/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9886 - loss: 0.0173 - val_accuracy: 0.7678 - val_loss: 1.6848
# Epoch 198/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9901 - loss: 0.0160 - val_accuracy: 0.7404 - val_loss: 1.8485
# Epoch 199/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9884 - loss: 0.0143 - val_accuracy: 0.7459 - val_loss: 2.0798
# Epoch 200/200
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9880 - loss: 0.0209 - val_accuracy: 0.7486 - val_loss: 1.9095

# %% [markdown]
# ## Visualize training results

# %% [markdown]
# Create plots of the loss and accuracy on the training and validation sets:

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(12, 12))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# The plots show that training accuracy and validation accuracy are off by large margins, and the model has achieved only around 60% accuracy on the validation set.
#
# The following tutorial sections show how to inspect what went wrong and try to increase the overall performance of the model.

# %% [markdown]
# -----------------
# -----------------
# -----------------

# %% [markdown]
# -----------------
# -----------------
# -----------------

# %% [markdown]
# -----------------
# -----------------
# -----------------

# %% [markdown]
# ## Predict on new data

# %%
# !git clone https://github.com/radhakrishnan-omotec/fundus-repo.git
# Out:
# Cloning into 'fundus-repo'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 58 (delta 20), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 50.01 MiB | 15.46 MiB/s, done.
# Resolving deltas: 100% (20/20), done.

# %% [markdown]
# Use your model to classify an image that wasn't included in the training or validation sets.

# %% [markdown]
# Note: Data augmentation and dropout layers are inactive at inference time.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        # Calculate confidence as a percentage
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/mild_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Mild'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 0024cdab0c1e.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        # Calculate confidence as a percentage
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/moderate_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Moderate'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 000c1434d8d7.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        # Calculate confidence as a percentage
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/No_DR_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/No_DR'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 002c21358ce6.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/Proliferate_DR_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Proliferate_DR'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 001639a390f0.png with 100.00% confidence.

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image

# Load and preprocess the uploaded image
def load_and_preprocess_image(img_path, target_size):
    img = tf.keras.utils.load_img(img_path, target_size=target_size)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch
    return img_array

# Compare two images using Mean Squared Error (MSE)
def mse(imageA, imageB):
    return np.mean((imageA - imageB) ** 2)

# Check if the uploaded image is in the dataset
def is_image_in_dataset(uploaded_img_path, dataset_dir, target_size):
    uploaded_img_array = load_and_preprocess_image(uploaded_img_path, target_size)
    uploaded_img_array = uploaded_img_array[0]  # Remove batch dimension

    best_match_error = float('inf')
    matched_filename = None

    for filename in os.listdir(dataset_dir):
        dataset_img_path = os.path.join(dataset_dir, filename)

        # Skip if it's not a file
        if not os.path.isfile(dataset_img_path):
            continue

        try:
            dataset_img_array = load_and_preprocess_image(dataset_img_path, target_size)
            dataset_img_array = dataset_img_array[0]  # Remove batch dimension

            # Calculate MSE
            error = mse(uploaded_img_array, dataset_img_array)

            # Check if it's the best match so far
            if error < best_match_error:
                best_match_error = error
                matched_filename = filename

        except (OSError, tf.errors.InvalidArgumentError):
            # Skip files that cannot be opened or are invalid images
            continue

    if matched_filename is not None:
        confidence = 100 * (1 - best_match_error / np.mean(np.square(uploaded_img_array)))
        return True, matched_filename, confidence
    else:
        return False, None, 0.0

# Example usage
if __name__ == "__main__":
    # Example uploaded image path
    uploaded_img_path = "/content/fundus-repo/Severe_retinopathy_test_image.png"

    # Example dataset directory containing images
    dataset_dir = '/content/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images/Severe'

    # Example target size
    target_size = (224, 224)

    # Check if uploaded image matches any image in the dataset
    is_match, matched_filename, confidence = is_image_in_dataset(uploaded_img_path, dataset_dir, target_size)

    if is_match:
        print(f"The uploaded image matches the dataset image: {matched_filename} with {confidence:.2f}% confidence.")
    else:
        print("The uploaded image does not match any image in the dataset.")
# Out:
# The uploaded image matches the dataset image: 0104b032c141.png with 100.00% confidence.

# %% [markdown]
# This code compares an uploaded image to each image in a dataset using Mean Squared Error to determine if they match, returning the filename of any matching image. It preprocesses images to a specified size and handles non-file entries and errors gracefully.

# %% [markdown]
# ## Use TensorFlow Lite
#
# TensorFlow Lite is a set of tools that enables on-device machine learning by helping developers run their models on mobile, embedded, and edge devices.

# %% [markdown]
# ### Convert the Keras Sequential model to a TensorFlow Lite model
#
# To use the trained model with on-device applications, first [convert it](https://www.tensorflow.org/lite/models/convert) to a smaller and more efficient model format called a [TensorFlow Lite](https://www.tensorflow.org/lite/) model.
#
# In this example, take the trained Keras Sequential model and use `tf.lite.TFLiteConverter.from_keras_model` to generate a [TensorFlow Lite](https://www.tensorflow.org/lite/) model:

# %%
# Convert the model.
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the model.
with open('model_fundus_level0.tflite', 'wb') as f:
  f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmpq9szjglw'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 180, 180, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   136020403437200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136020403568464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136020403556560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136020403431632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136020403421456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136020403432592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136020403432976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136020403435472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136020403547472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136020403543632: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %% [markdown]
# The TensorFlow Lite model you saved in the previous step can contain several function signatures. The Keras model converter API uses the default signature automatically. Learn more about [TensorFlow Lite signatures](https://www.tensorflow.org/lite/guide/signatures).

# %% [markdown]
# ### Run the TensorFlow Lite model
#
# You can access the TensorFlow Lite saved model signatures in Python via the `tf.lite.Interpreter` class.
#
# Load the model with the `Interpreter`:

# %%
TF_MODEL_FILE_PATH = 'model_fundus_level0.tflite' # The default path to the saved TensorFlow Lite model

interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)

# %% [markdown]
# Print the signatures from the converted model to obtain the names of the inputs (and outputs):

# %%
interpreter.get_signature_list()
# Out:
# {'serving_default': {'inputs': ['keras_tensor'], 'outputs': ['output_0']}}

# %% [markdown]
# In this example, you have one default signature called `serving_default`. In addition, the name of the `'inputs'` is `'sequential_1_input'`, while the `'outputs'` are called `'outputs'`. You can look up these first and last Keras layer names when running `Model.summary`, as demonstrated earlier in this tutorial.
#
# Now you can test the loaded TensorFlow Model by performing inference on a sample image with `tf.lite.Interpreter.get_signature_runner` by passing the signature name as follows:

# %%
classify_lite = interpreter.get_signature_runner('serving_default')
classify_lite

# %% [markdown]
# #Prediction Testing Phase

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Prediction with webcam Fundus images

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Define the paths
image_path = '/content/fundus-repo/Proliferate_DR_retinopathy_test_image.png'  # Replace with your actual image path
TF_MODEL_FILE_PATH = 'model_fundus_level0.tflite'  # The default path to the saved TensorFlow Lite model

# Define class names corresponding to your model output
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = Image.open(img_path).convert('RGB')
    img = img.resize(target_size)
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# Preprocess the image
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (batch_size, height, width, channels)
image_data = load_and_preprocess_image(image_path, input_shape)

# Ensure the input tensor's type matches the model's expected type
input_data = image_data.astype(input_details[0]['dtype'])

# Set input tensor
interpreter.set_tensor(input_details[0]['index'], input_data)

# Run inference
interpreter.invoke()

# Get the output tensor
output_data = interpreter.get_tensor(output_details[0]['index'])

# Get predicted class index
predicted_class_index = np.argmax(output_data[0])
predicted_class_name = class_names[predicted_class_index]

print(f"Predicted class index: {predicted_class_index}")
print(f"Predicted class name: {predicted_class_name}")

# Show the image along with the prediction
img = Image.open(image_path)
plt.imshow(img)
plt.title(f"Predicted: {predicted_class_name}")
plt.axis('off')
plt.show()
# Out:
# Predicted class index: 1
# Predicted class name: Mild

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Define the paths
image_path = '/content/fundus-repo/mild_retinopathy_test_image.png'  # Replace with your actual image path
TF_MODEL_FILE_PATH = 'model_fundus_level0.tflite'  # The default path to the saved TensorFlow Lite model

# Define class names corresponding to your model output
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = Image.open(img_path).convert('RGB')
    img = img.resize(target_size)
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# Preprocess the image
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (batch_size, height, width, channels)
image_data = load_and_preprocess_image(image_path, input_shape)

# Ensure the input tensor's type matches the model's expected type
input_data = image_data.astype(input_details[0]['dtype'])

# Set input tensor
interpreter.set_tensor(input_details[0]['index'], input_data)

# Run inference
interpreter.invoke()

# Get the output tensor
output_data = interpreter.get_tensor(output_details[0]['index'])

# Get predicted class index
predicted_class_index = np.argmax(output_data[0])
predicted_class_name = class_names[predicted_class_index]

print(f"Predicted class index: {predicted_class_index}")
print(f"Predicted class name: {predicted_class_name}")

# Show the image along with the prediction
img = Image.open(image_path)
plt.imshow(img)
plt.title(f"Predicted: {predicted_class_name}")
plt.axis('off')
plt.show()
# Out:
# Predicted class index: 1
# Predicted class name: Mild

# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Define the paths
image_path = '/content/fundus-repo/No_DR_retinopathy_test_image.png'  # Replace with your actual image path
TF_MODEL_FILE_PATH = 'model_fundus_level0.tflite'  # The default path to the saved TensorFlow Lite model

# Define class names corresponding to your model output
class_names = ['No_DR', 'Mild', 'Moderate', 'Severe', 'Proliferate_DR']  # Replace with actual class names

# Load the TensorFlow Lite model
interpreter = tf.lite.Interpreter(model_path=TF_MODEL_FILE_PATH)
interpreter.allocate_tensors()

# Get input and output tensors
input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

# Load and preprocess the image
def load_and_preprocess_image(img_path, target_size):
    img = Image.open(img_path).convert('RGB')
    img = img.resize(target_size)
    img_array = np.array(img).astype(np.float32)

    # Normalize the image if the model expects it (e.g., values between 0 and 1)
    img_array /= 255.0

    img_array = np.expand_dims(img_array, axis=0)
    return img_array

# Preprocess the image
input_shape = input_details[0]['shape'][1:3]  # Assuming input shape (batch_size, height, width, channels)
image_data = load_and_preprocess_image(image_path, input_shape)

# Ensure the input tensor's type matches the model's expected type
input_data = image_data.astype(input_details[0]['dtype'])

# Set input tensor
interpreter.set_tensor(input_details[0]['index'], input_data)

# Run inference
interpreter.invoke()

# Get the output tensor
output_data = interpreter.get_tensor(output_details[0]['index'])

# Get predicted class index
predicted_class_index = np.argmax(output_data[0])
predicted_class_name = class_names[predicted_class_index]

print(f"Predicted class index: {predicted_class_index}")
print(f"Predicted class name: {predicted_class_name}")

# Show the image along with the prediction
img = Image.open(image_path)
plt.imshow(img)
plt.title(f"Predicted: {predicted_class_name}")
plt.axis('off')
plt.show()
# Out:
# Predicted class index: 1
# Predicted class name: Mild

# %% [markdown]
# Similar to what you did earlier in the tutorial, you can use the TensorFlow Lite model to classify images that weren't included in the training or validation sets.
#
# You have already tensorized that image and saved it as `img_array`. Now, pass it to the first argument (the name of the `'inputs'`) of the loaded TensorFlow Lite model (`predictions_lite`), compute softmax activations, and then print the prediction for the class with the highest computed probability.

# %% [markdown]
# Of the five classes—`'No_DR'`, `'Mild'`, `'Moderate'`, `' Severe'` and `'Proliferate_DR'`
